# %%
import pandas as pd
import requests
import finnhub
import time
import urllib
from datetime import datetime
from datetime import date
from datetime import timedelta
pd.set_option('display.max_rows', None)
import pymongo

#user = db['user']
#symbols = db['symbols']
#app = db['app']
#fh = finnhub.Client(api_key="c5tec52ad3ifck7dehd0")
#dataLoc = '../Data/'
#favList = user.find_one({})['favorites']
#lastSyncDate = app.find_one({})['lastSyncDate']

# %%
username = "kxerxess"
password = "Theakatsuki99"
host = "cluster0.zvabl.mongodb.net"
db = "crypto_dashboard"

# %%
connection_string = (
            "mongodb+srv://"
            + username
            + ":"
            + urllib.parse.quote(password)
            + "@"
            + host
            + "/"
            + db
            + "?retryWrites=true&w=majority"
        )
client = pymongo.MongoClient(connection_string)
db = client['crypto_dashboard']

# %%
user = db['user']
app = db['app']
symbols = db['symbols']

# %%
res = self.fh.crypto_symbols("BINANCE")
data = list()
for each in res:
    display = each["displaySymbol"]
    symbol = each["symbol"]
    base = display.split("/")[0]
    quote = display.split("/")[1]
    if quote == "USDT":
        data.append(
            {
                "display": display,
                "base": base,
                "quote": quote,
                "symbol": symbol,
            }
        )
# Out:
# [{'description': 'Binance DCR/USDT',
#   'displaySymbol': 'DCR/USDT',
#   'symbol': 'BINANCE:DCRUSDT'},
#  {'description': 'Binance TNB/BTC',
#   'displaySymbol': 'TNB/BTC',
#   'symbol': 'BINANCE:TNBBTC'},
#  {'description': 'Binance HC/ETH',
#   'displaySymbol': 'HC/ETH',
#   'symbol': 'BINANCE:HCETH'},
#  {'description': 'Binance GLM/ETH',
#   'displaySymbol': 'GLM/ETH',
#   'symbol': 'BINANCE:GLMETH'},
#  {'description': 'Binance CHESS/BNB',
#   'displaySymbol': 'CHESS/BNB',
#   'symbol': 'BINANCE:CHESSBNB'},
#  {'description': 'Binance TKO/BTC',
#   'displaySymbol': 'TKO/BTC',
#   'symbol': 'BINANCE:TKOBTC'},
#  {'description': 'Binance KNC/BTC',
#   'displaySymbol': 'KNC/BTC',
#   'symbol': 'BINANCE:KNCBTC'},
#  {'description': 'Binance ETC/GBP',
#   'displaySymbol': 'ETC/GBP',
#   'symbol': 'BINANCE:ETCGBP'},
#  {'description': 'Binance KEEP/BTC',
#   'displaySymbol': 'KEEP/BTC',
#   'symbol': 'BINANCE:KEEPBTC'},
#  {'description': 'Binance PPT/ETH',
#   'displaySymbol': 'PPT/ETH',
#   'symbol': 'BINANCE:PPTETH'},
#  {'description': 'Binance HEGIC/BUSD',
#   'displaySymbol': 'HEGIC/BUSD',
#   'symbol': 'BINANCE:HEGICBUSD'},
#  {'description': 'Binance QUICK/BNB',
#   'displaySymbol': 'QUICK/BNB',
#   'symbol': 'BINANCE:QUICKBNB'},
#  {'description': 'Binance BETH/ETH',
#   'displaySymbol': 'BETH/ETH',
#   'symbol': 'BINANCE:BETHETH'},
#  {'description': 'Binance LSK/BNB',
#   'displaySymbol': 'LSK/BNB',
#   'symbol': 'BINANCE:LSKBNB'},
#  {'description': 'Binance YFII/BNB',
#   'displaySymbol': 'YFII/BNB',
#   'symbol': 'BINANCE:YFIIBNB'},
#  {'description': 'Binance BIFI/BUSD',
#   'displaySymbol': 'BIFI/BUSD',
#   'symbol': 'BINANCE:BIFIBUSD'},
#  {'description': 'Binance VEN/BNB',
#   'displaySymbol': 'VEN/BNB',
#   'symbol': 'BINANCE:VENBNB'},
#  {'description': 'Binance XEM/USDT',
#   'displaySymbol': 'XEM/USDT',
#   'symbol': 'BINANCE:XEMUSDT'},
#  {'description': 'Binance ACM/USDT',
#   'displaySymbol': 'ACM/USDT',
#   'symbol': 'BINANCE:ACMUSDT'},
#  {'description': 'Binance BIFI/BNB',
#   'displaySymbol': 'BIFI/BNB',
#   'symbol': 'BINANCE:BIFIBNB'},
#  {'description': 'Binance ALICE/BUSD',
#   'displaySymbol': 'ALICE/BUSD',
#   'symbol': 'BINANCE:ALICEBUSD'},
#  {'description': 'Binance NEO/BNB',
#   'displaySymbol': 'NEO/BNB',
#   'symbol': 'BINANCE:NEOBNB'},
#  {'description': 'Binance VET/USDT',
#   'displaySymbol': 'VET/USDT',
#   'symbol': 'BINANCE:VETUSDT'},
#  {'description': 'Binance FORTH/USDT',
#   'displaySymbol': 'FORTH/USDT',
#   'symbol': 'BINANCE:FORTHUSDT'},
#  {'description': 'Binance ENJ/BNB',
#   'displaySymbol': 'ENJ/BNB',
#   'symbol': 'BINANCE:ENJBNB'},
#  {'description': 'Binance USDT/DAI',
#   'displaySymbol': 'USDT/DAI',
#   'symbol': 'BINANCE:USDTDAI'},
#  {'description': 'Binance DUSK/USDT',
#   'displaySymbol': 'DUSK/USDT',
#   'symbol': 'BINANCE:DUSKUSDT'},
#  {'description': 'Binance WAVES/BUSD',
#   'displaySymbol': 'WAVES/BUSD',
#   'symbol': 'BINANCE:WAVESBUSD'},
#  {'description': 'Binance BNT/ETH',
#   'displaySymbol': 'BNT/ETH',
#   'symbol': 'BINANCE:BNTETH'},
#  {'description': 'Binance SHIB/RUB',
#   'displaySymbol': 'SHIB/RUB',
#   'symbol': 'BINANCE:SHIBRUB'},
#  {'description': 'Binance GVT/BTC',
#   'displaySymbol': 'GVT/BTC',
#   'symbol': 'BINANCE:GVTBTC'},
#  {'description': 'Binance SOL/BNB',
#   'displaySymbol': 'SOL/BNB',
#   'symbol': 'BINANCE:SOLBNB'},
#  {'description': 'Binance LTC/TUSD',
#   'displaySymbol': 'LTC/TUSD',
#   'symbol': 'BINANCE:LTCTUSD'},
#  {'description': 'Binance BAR/BUSD',
#   'displaySymbol': 'BAR/BUSD',
#   'symbol': 'BINANCE:BARBUSD'},
#  {'description': 'Binance BCH/USDC',
#   'displaySymbol': 'BCH/USDC',
#   'symbol': 'BINANCE:BCHUSDC'},
#  {'description': 'Binance BAND/BTC',
#   'displaySymbol': 'BAND/BTC',
#   'symbol': 'BINANCE:BANDBTC'},
#  {'description': 'Binance UNI/EUR',
#   'displaySymbol': 'UNI/EUR',
#   'symbol': 'BINANCE:UNIEUR'},
#  {'description': 'Binance ALGO/USDT',
#   'displaySymbol': 'ALGO/USDT',
#   'symbol': 'BINANCE:ALGOUSDT'},
#  {'description': 'Binance QSP/BNB',
#   'displaySymbol': 'QSP/BNB',
#   'symbol': 'BINANCE:QSPBNB'},
#  {'description': 'Binance ALPACA/BTC',
#   'displaySymbol': 'ALPACA/BTC',
#   'symbol': 'BINANCE:ALPACABTC'},
#  {'description': 'Binance BAR/USDT',
#   'displaySymbol': 'BAR/USDT',
#   'symbol': 'BINANCE:BARUSDT'},
#  {'description': 'Binance AST/BTC',
#   'displaySymbol': 'AST/BTC',
#   'symbol': 'BINANCE:ASTBTC'},
#  {'description': 'Binance COMP/BNB',
#   'displaySymbol': 'COMP/BNB',
#   'symbol': 'BINANCE:COMPBNB'},
#  {'description': 'Binance APPC/ETH',
#   'displaySymbol': 'APPC/ETH',
#   'symbol': 'BINANCE:APPCETH'},
#  {'description': 'Binance LRC/USDT',
#   'displaySymbol': 'LRC/USDT',
#   'symbol': 'BINANCE:LRCUSDT'},
#  {'description': 'Binance IDEX/USDT',
#   'displaySymbol': 'IDEX/USDT',
#   'symbol': 'BINANCE:IDEXUSDT'},
#  {'description': 'Binance ETH/BKRW',
#   'displaySymbol': 'ETH/BKRW',
#   'symbol': 'BINANCE:ETHBKRW'},
#  {'description': 'Binance ICP/BUSD',
#   'displaySymbol': 'ICP/BUSD',
#   'symbol': 'BINANCE:ICPBUSD'},
#  {'description': 'Binance DLT/BNB',
#   'displaySymbol': 'DLT/BNB',
#   'symbol': 'BINANCE:DLTBNB'},
#  {'description': 'Binance YOYO/BNB',
#   'displaySymbol': 'YOYO/BNB',
#   'symbol': 'BINANCE:YOYOBNB'},
#  {'description': 'Binance WNXM/BTC',
#   'displaySymbol': 'WNXM/BTC',
#   'symbol': 'BINANCE:WNXMBTC'},
#  {'description': 'Binance DASH/BUSD',
#   'displaySymbol': 'DASH/BUSD',
#   'symbol': 'BINANCE:DASHBUSD'},
#  {'description': 'Binance SNM/BTC',
#   'displaySymbol': 'SNM/BTC',
#   'symbol': 'BINANCE:SNMBTC'},
#  {'description': 'Binance 1INCH/BTC',
#   'displaySymbol': '1INCH/BTC',
#   'symbol': 'BINANCE:1INCHBTC'},
#  {'description': 'Binance MATIC/BIDR',
#   'displaySymbol': 'MATIC/BIDR',
#   'symbol': 'BINANCE:MATICBIDR'},
#  {'description': 'Binance MDT/BNB',
#   'displaySymbol': 'MDT/BNB',
#   'symbol': 'BINANCE:MDTBNB'},
#  {'description': 'Binance ETHBEAR/BUSD',
#   'displaySymbol': 'ETHBEAR/BUSD',
#   'symbol': 'BINANCE:ETHBEARBUSD'},
#  {'description': 'Binance USDT/BRL',
#   'displaySymbol': 'USDT/BRL',
#   'symbol': 'BINANCE:USDTBRL'},
#  {'description': 'Binance MATIC/TRY',
#   'displaySymbol': 'MATIC/TRY',
#   'symbol': 'BINANCE:MATICTRY'},
#  {'description': 'Binance BCHABC/USDC',
#   'displaySymbol': 'BCHABC/USDC',
#   'symbol': 'BINANCE:BCHABCUSDC'},
#  {'description': 'Binance PAX/ETH',
#   'displaySymbol': 'PAX/ETH',
#   'symbol': 'BINANCE:PAXETH'},
#  {'description': 'Binance TFUEL/PAX',
#   'displaySymbol': 'TFUEL/PAX',
#   'symbol': 'BINANCE:TFUELPAX'},
#  {'description': 'Binance BETA/BNB',
#   'displaySymbol': 'BETA/BNB',
#   'symbol': 'BINANCE:BETABNB'},
#  {'description': 'Binance WIN/USDT',
#   'displaySymbol': 'WIN/USDT',
#   'symbol': 'BINANCE:WINUSDT'},
#  {'description': 'Binance CELR/BNB',
#   'displaySymbol': 'CELR/BNB',
#   'symbol': 'BINANCE:CELRBNB'},
#  {'description': 'Binance STORJ/BUSD',
#   'displaySymbol': 'STORJ/BUSD',
#   'symbol': 'BINANCE:STORJBUSD'},
#  {'description': 'Binance MINA/BUSD',
#   'displaySymbol': 'MINA/BUSD',
#   'symbol': 'BINANCE:MINABUSD'},
#  {'description': 'Binance XRPUP/USDT',
#   'displaySymbol': 'XRPUP/USDT',
#   'symbol': 'BINANCE:XRPUPUSDT'},
#  {'description': 'Binance HBAR/BUSD',
#   'displaySymbol': 'HBAR/BUSD',
#   'symbol': 'BINANCE:HBARBUSD'},
#  {'description': 'Binance FLOW/BUSD',
#   'displaySymbol': 'FLOW/BUSD',
#   'symbol': 'BINANCE:FLOWBUSD'},
#  {'description': 'Binance CTK/BTC',
#   'displaySymbol': 'CTK/BTC',
#   'symbol': 'BINANCE:CTKBTC'},
#  {'description': 'Binance MBOX/BTC',
#   'displaySymbol': 'MBOX/BTC',
#   'symbol': 'BINANCE:MBOXBTC'},
#  {'description': 'Binance XTZDOWN/USDT',
#   'displaySymbol': 'XTZDOWN/USDT',
#   'symbol': 'BINANCE:XTZDOWNUSDT'},
#  {'description': 'Binance ARPA/TRY',
#   'displaySymbol': 'ARPA/TRY',
#   'symbol': 'BINANCE:ARPATRY'},
#  {'description': 'Binance IOTX/BUSD',
#   'displaySymbol': 'IOTX/BUSD',
#   'symbol': 'BINANCE:IOTXBUSD'},
#  {'description': 'Binance ANT/USDT',
#   'displaySymbol': 'ANT/USDT',
#   'symbol': 'BINANCE:ANTUSDT'},
#  {'description': 'Binance LUN/BTC',
#   'displaySymbol': 'LUN/BTC',
#   'symbol': 'BINANCE:LUNBTC'},
#  {'description': 'Binance GTC/USDT',
#   'displaySymbol': 'GTC/USDT',
#   'symbol': 'BINANCE:GTCUSDT'},
#  {'description': 'Binance DODO/BUSD',
#   'displaySymbol': 'DODO/BUSD',
#   'symbol': 'BINANCE:DODOBUSD'},
#  {'description': 'Binance FTT/BTC',
#   'displaySymbol': 'FTT/BTC',
#   'symbol': 'BINANCE:FTTBTC'},
#  {'description': 'Binance AERGO/BUSD',
#   'displaySymbol': 'AERGO/BUSD',
#   'symbol': 'BINANCE:AERGOBUSD'},
#  {'description': 'Binance TRU/USDT',
#   'displaySymbol': 'TRU/USDT',
#   'symbol': 'BINANCE:TRUUSDT'},
#  {'description': 'Binance NPXS/BTC',
#   'displaySymbol': 'NPXS/BTC',
#   'symbol': 'BINANCE:NPXSBTC'},
#  {'description': 'Binance YOYO/ETH',
#   'displaySymbol': 'YOYO/ETH',
#   'symbol': 'BINANCE:YOYOETH'},
#  {'description': 'Binance BOND/USDT',
#   'displaySymbol': 'BOND/USDT',
#   'symbol': 'BINANCE:BONDUSDT'},
#  {'description': 'Binance AVAX/EUR',
#   'displaySymbol': 'AVAX/EUR',
#   'symbol': 'BINANCE:AVAXEUR'},
#  {'description': 'Binance STRAT/BNB',
#   'displaySymbol': 'STRAT/BNB',
#   'symbol': 'BINANCE:STRATBNB'},
#  {'description': 'Binance EPS/BTC',
#   'displaySymbol': 'EPS/BTC',
#   'symbol': 'BINANCE:EPSBTC'},
#  {'description': 'Binance EOS/BUSD',
#   'displaySymbol': 'EOS/BUSD',
#   'symbol': 'BINANCE:EOSBUSD'},
#  {'description': 'Binance SAND/BNB',
#   'displaySymbol': 'SAND/BNB',
#   'symbol': 'BINANCE:SANDBNB'},
#  {'description': 'Binance SOL/ETH',
#   'displaySymbol': 'SOL/ETH',
#   'symbol': 'BINANCE:SOLETH'},
#  {'description': 'Binance FORTH/BUSD',
#   'displaySymbol': 'FORTH/BUSD',
#   'symbol': 'BINANCE:FORTHBUSD'},
#  {'description': 'Binance YFII/BTC',
#   'displaySymbol': 'YFII/BTC',
#   'symbol': 'BINANCE:YFIIBTC'},
#  {'description': 'Binance KEY/BTC',
#   'displaySymbol': 'KEY/BTC',
#   'symbol': 'BINANCE:KEYBTC'},
#  {'description': 'Binance DREP/BNB',
#   'displaySymbol': 'DREP/BNB',
#   'symbol': 'BINANCE:DREPBNB'},
#  {'description': 'Binance OMG/BNB',
#   'displaySymbol': 'OMG/BNB',
#   'symbol': 'BINANCE:OMGBNB'},
#  {'description': 'Binance EASY/BTC',
#   'displaySymbol': 'EASY/BTC',
#   'symbol': 'BINANCE:EASYBTC'},
#  {'description': 'Binance RCN/BNB',
#   'displaySymbol': 'RCN/BNB',
#   'symbol': 'BINANCE:RCNBNB'},
#  {'description': 'Binance EOS/TUSD',
#   'displaySymbol': 'EOS/TUSD',
#   'symbol': 'BINANCE:EOSTUSD'},
#  {'description': 'Binance EPS/USDT',
#   'displaySymbol': 'EPS/USDT',
#   'symbol': 'BINANCE:EPSUSDT'},
#  {'description': 'Binance PHX/BTC',
#   'displaySymbol': 'PHX/BTC',
#   'symbol': 'BINANCE:PHXBTC'},
#  {'description': 'Binance CRV/BTC',
#   'displaySymbol': 'CRV/BTC',
#   'symbol': 'BINANCE:CRVBTC'},
#  {'description': 'Binance BUSD/BRL',
#   'displaySymbol': 'BUSD/BRL',
#   'symbol': 'BINANCE:BUSDBRL'},
#  {'description': 'Binance WAXP/BUSD',
#   'displaySymbol': 'WAXP/BUSD',
#   'symbol': 'BINANCE:WAXPBUSD'},
#  {'description': 'Binance EGLD/BUSD',
#   'displaySymbol': 'EGLD/BUSD',
#   'symbol': 'BINANCE:EGLDBUSD'},
#  {'description': 'Binance KMD/BUSD',
#   'displaySymbol': 'KMD/BUSD',
#   'symbol': 'BINANCE:KMDBUSD'},
#  {'description': 'Binance DOTDOWN/USDT',
#   'displaySymbol': 'DOTDOWN/USDT',
#   'symbol': 'BINANCE:DOTDOWNUSDT'},
#  {'description': 'Binance MCO/BTC',
#   'displaySymbol': 'MCO/BTC',
#   'symbol': 'BINANCE:MCOBTC'},
#  {'description': 'Binance ALGO/BTC',
#   'displaySymbol': 'ALGO/BTC',
#   'symbol': 'BINANCE:ALGOBTC'},
#  {'description': 'Binance VET/TRY',
#   'displaySymbol': 'VET/TRY',
#   'symbol': 'BINANCE:VETTRY'},
#  {'description': 'Binance CTK/BUSD',
#   'displaySymbol': 'CTK/BUSD',
#   'symbol': 'BINANCE:CTKBUSD'},
#  {'description': 'Binance DOT/USDT',
#   'displaySymbol': 'DOT/USDT',
#   'symbol': 'BINANCE:DOTUSDT'},
#  {'description': 'Binance FET/BUSD',
#   'displaySymbol': 'FET/BUSD',
#   'symbol': 'BINANCE:FETBUSD'},
#  {'description': 'Binance TRX/XRP',
#   'displaySymbol': 'TRX/XRP',
#   'symbol': 'BINANCE:TRXXRP'},
#  {'description': 'Binance ADA/TRY',
#   'displaySymbol': 'ADA/TRY',
#   'symbol': 'BINANCE:ADATRY'},
#  {'description': 'Binance VIDT/BTC',
#   'displaySymbol': 'VIDT/BTC',
#   'symbol': 'BINANCE:VIDTBTC'},
#  {'description': 'Binance RVN/TRY',
#   'displaySymbol': 'RVN/TRY',
#   'symbol': 'BINANCE:RVNTRY'},
#  {'description': 'Binance SXPUP/USDT',
#   'displaySymbol': 'SXPUP/USDT',
#   'symbol': 'BINANCE:SXPUPUSDT'},
#  {'description': 'Binance XRP/BUSD',
#   'displaySymbol': 'XRP/BUSD',
#   'symbol': 'BINANCE:XRPBUSD'},
#  {'description': 'Binance BQX/BTC',
#   'displaySymbol': 'BQX/BTC',
#   'symbol': 'BINANCE:BQXBTC'},
#  {'description': 'Binance MASK/USDT',
#   'displaySymbol': 'MASK/USDT',
#   'symbol': 'BINANCE:MASKUSDT'},
#  {'description': 'Binance SSV/BTC',
#   'displaySymbol': 'SSV/BTC',
#   'symbol': 'BINANCE:SSVBTC'},
#  {'description': 'Binance LINK/GBP',
#   'displaySymbol': 'LINK/GBP',
#   'symbol': 'BINANCE:LINKGBP'},
#  {'description': 'Binance LUNA/EUR',
#   'displaySymbol': 'LUNA/EUR',
#   'symbol': 'BINANCE:LUNAEUR'},
#  {'description': 'Binance BTC/RUB',
#   'displaySymbol': 'BTC/RUB',
#   'symbol': 'BINANCE:BTCRUB'},
#  {'description': 'Binance USDT/BVND',
#   'displaySymbol': 'USDT/BVND',
#   'symbol': 'BINANCE:USDTBVND'},
#  {'description': 'Binance STMX/ETH',
#   'displaySymbol': 'STMX/ETH',
#   'symbol': 'BINANCE:STMXETH'},
#  {'description': 'Binance EASY/ETH',
#   'displaySymbol': 'EASY/ETH',
#   'symbol': 'BINANCE:EASYETH'},
#  {'description': 'Binance ONT/BNB',
#   'displaySymbol': 'ONT/BNB',
#   'symbol': 'BINANCE:ONTBNB'},
#  {'description': 'Binance LINA/USDT',
#   'displaySymbol': 'LINA/USDT',
#   'symbol': 'BINANCE:LINAUSDT'},
#  {'description': 'Binance WAVES/TUSD',
#   'displaySymbol': 'WAVES/TUSD',
#   'symbol': 'BINANCE:WAVESTUSD'},
#  {'description': 'Binance UNIDOWN/USDT',
#   'displaySymbol': 'UNIDOWN/USDT',
#   'symbol': 'BINANCE:UNIDOWNUSDT'},
#  {'description': 'Binance BNB/BRL',
#   'displaySymbol': 'BNB/BRL',
#   'symbol': 'BINANCE:BNBBRL'},
#  {'description': 'Binance XLM/PAX',
#   'displaySymbol': 'XLM/PAX',
#   'symbol': 'BINANCE:XLMPAX'},
#  {'description': 'Binance PNT/USDT',
#   'displaySymbol': 'PNT/USDT',
#   'symbol': 'BINANCE:PNTUSDT'},
#  {'description': 'Binance HSR/BTC',
#   'displaySymbol': 'HSR/BTC',
#   'symbol': 'BINANCE:HSRBTC'},
#  {'description': 'Binance LINK/BUSD',
#   'displaySymbol': 'LINK/BUSD',
#   'symbol': 'BINANCE:LINKBUSD'},
#  {'description': 'Binance CLV/BNB',
#   'displaySymbol': 'CLV/BNB',
#   'symbol': 'BINANCE:CLVBNB'},
#  {'description': 'Binance BUSD/VAI',
#   'displaySymbol': 'BUSD/VAI',
#   'symbol': 'BINANCE:BUSDVAI'},
#  {'description': 'Binance DOTUP/USDT',
#   'displaySymbol': 'DOTUP/USDT',
#   'symbol': 'BINANCE:DOTUPUSDT'},
#  {'description': 'Binance POLS/BNB',
#   'displaySymbol': 'POLS/BNB',
#   'symbol': 'BINANCE:POLSBNB'},
#  {'description': 'Binance QNT/BUSD',
#   'displaySymbol': 'QNT/BUSD',
#   'symbol': 'BINANCE:QNTBUSD'},
#  {'description': 'Binance SXP/BTC',
#   'displaySymbol': 'SXP/BTC',
#   'symbol': 'BINANCE:SXPBTC'},
#  {'description': 'Binance STX/BNB',
#   'displaySymbol': 'STX/BNB',
#   'symbol': 'BINANCE:STXBNB'},
#  {'description': 'Binance KLAY/BNB',
#   'displaySymbol': 'KLAY/BNB',
#   'symbol': 'BINANCE:KLAYBNB'},
#  {'description': 'Binance CTSI/USDT',
#   'displaySymbol': 'CTSI/USDT',
#   'symbol': 'BINANCE:CTSIUSDT'},
#  {'description': 'Binance AGIX/BTC',
#   'displaySymbol': 'AGIX/BTC',
#   'symbol': 'BINANCE:AGIXBTC'},
#  {'description': 'Binance LINK/NGN',
#   'displaySymbol': 'LINK/NGN',
#   'symbol': 'BINANCE:LINKNGN'},
#  {'description': 'Binance ILV/BUSD',
#   'displaySymbol': 'ILV/BUSD',
#   'symbol': 'BINANCE:ILVBUSD'},
#  {'description': 'Binance XTZ/BUSD',
#   'displaySymbol': 'XTZ/BUSD',
#   'symbol': 'BINANCE:XTZBUSD'},
#  {'description': 'Binance DASH/BNB',
#   'displaySymbol': 'DASH/BNB',
#   'symbol': 'BINANCE:DASHBNB'},
#  {'description': 'Binance BTC/USDC',
#   'displaySymbol': 'BTC/USDC',
#   'symbol': 'BINANCE:BTCUSDC'},
#  {'description': 'Binance KMD/USDT',
#   'displaySymbol': 'KMD/USDT',
#   'symbol': 'BINANCE:KMDUSDT'},
#  {'description': 'Binance RUNE/BNB',
#   'displaySymbol': 'RUNE/BNB',
#   'symbol': 'BINANCE:RUNEBNB'},
#  {'description': 'Binance ZEN/ETH',
#   'displaySymbol': 'ZEN/ETH',
#   'symbol': 'BINANCE:ZENETH'},
#  {'description': 'Binance RVN/USDT',
#   'displaySymbol': 'RVN/USDT',
#   'symbol': 'BINANCE:RVNUSDT'},
#  {'description': 'Binance STRAT/ETH',
#   'displaySymbol': 'STRAT/ETH',
#   'symbol': 'BINANCE:STRATETH'},
#  {'description': 'Binance ONT/PAX',
#   'displaySymbol': 'ONT/PAX',
#   'symbol': 'BINANCE:ONTPAX'},
#  {'description': 'Binance AVAX/AUD',
#   'displaySymbol': 'AVAX/AUD',
#   'symbol': 'BINANCE:AVAXAUD'},
#  {'description': 'Binance INJ/USDT',
#   'displaySymbol': 'INJ/USDT',
#   'symbol': 'BINANCE:INJUSDT'},
#  {'description': 'Binance OMG/USDT',
#   'displaySymbol': 'OMG/USDT',
#   'symbol': 'BINANCE:OMGUSDT'},
#  {'description': 'Binance XRP/TUSD',
#   'displaySymbol': 'XRP/TUSD',
#   'symbol': 'BINANCE:XRPTUSD'},
#  {'description': 'Binance UNFI/BTC',
#   'displaySymbol': 'UNFI/BTC',
#   'symbol': 'BINANCE:UNFIBTC'},
#  {'description': 'Binance LOOM/BNB',
#   'displaySymbol': 'LOOM/BNB',
#   'symbol': 'BINANCE:LOOMBNB'},
#  {'description': 'Binance AVA/BTC',
#   'displaySymbol': 'AVA/BTC',
#   'symbol': 'BINANCE:AVABTC'},
#  {'description': 'Binance FTM/PAX',
#   'displaySymbol': 'FTM/PAX',
#   'symbol': 'BINANCE:FTMPAX'},
#  {'description': 'Binance ADA/EUR',
#   'displaySymbol': 'ADA/EUR',
#   'symbol': 'BINANCE:ADAEUR'},
#  {'description': 'Binance RSR/BNB',
#   'displaySymbol': 'RSR/BNB',
#   'symbol': 'BINANCE:RSRBNB'},
#  {'description': 'Binance LRC/BUSD',
#   'displaySymbol': 'LRC/BUSD',
#   'symbol': 'BINANCE:LRCBUSD'},
#  {'description': 'Binance OGN/BNB',
#   'displaySymbol': 'OGN/BNB',
#   'symbol': 'BINANCE:OGNBNB'},
#  {'description': 'Binance QLC/ETH',
#   'displaySymbol': 'QLC/ETH',
#   'symbol': 'BINANCE:QLCETH'},
#  {'description': 'Binance FTM/TUSD',
#   'displaySymbol': 'FTM/TUSD',
#   'symbol': 'BINANCE:FTMTUSD'},
#  {'description': 'Binance XRPDOWN/USDT',
#   'displaySymbol': 'XRPDOWN/USDT',
#   'symbol': 'BINANCE:XRPDOWNUSDT'},
#  {'description': 'Binance BNB/USDP',
#   'displaySymbol': 'BNB/USDP',
#   'symbol': 'BINANCE:BNBUSDP'},
#  {'description': 'Binance OCEAN/USDT',
#   'displaySymbol': 'OCEAN/USDT',
#   'symbol': 'BINANCE:OCEANUSDT'},
#  {'description': 'Binance SNX/BTC',
#   'displaySymbol': 'SNX/BTC',
#   'symbol': 'BINANCE:SNXBTC'},
#  {'description': 'Binance DOCK/BTC',
#   'displaySymbol': 'DOCK/BTC',
#   'symbol': 'BINANCE:DOCKBTC'},
#  {'description': 'Binance UNI/USDT',
#   'displaySymbol': 'UNI/USDT',
#   'symbol': 'BINANCE:UNIUSDT'},
#  {'description': 'Binance LINK/BKRW',
#   'displaySymbol': 'LINK/BKRW',
#   'symbol': 'BINANCE:LINKBKRW'},
#  {'description': 'Binance LTC/GBP',
#   'displaySymbol': 'LTC/GBP',
#   'symbol': 'BINANCE:LTCGBP'},
#  {'description': 'Binance BUSD/DAI',
#   'displaySymbol': 'BUSD/DAI',
#   'symbol': 'BINANCE:BUSDDAI'},
#  {'description': 'Binance AUDIO/BUSD',
#   'displaySymbol': 'AUDIO/BUSD',
#   'symbol': 'BINANCE:AUDIOBUSD'},
#  {'description': 'Binance GTC/BTC',
#   'displaySymbol': 'GTC/BTC',
#   'symbol': 'BINANCE:GTCBTC'},
#  {'description': 'Binance CTXC/BTC',
#   'displaySymbol': 'CTXC/BTC',
#   'symbol': 'BINANCE:CTXCBTC'},
#  {'description': 'Binance MITH/USDT',
#   'displaySymbol': 'MITH/USDT',
#   'symbol': 'BINANCE:MITHUSDT'},
#  {'description': 'Binance NBS/USDT',
#   'displaySymbol': 'NBS/USDT',
#   'symbol': 'BINANCE:NBSUSDT'},
#  {'description': 'Binance C98/BUSD',
#   'displaySymbol': 'C98/BUSD',
#   'symbol': 'BINANCE:C98BUSD'},
#  {'description': 'Binance BGBP/USDC',
#   'displaySymbol': 'BGBP/USDC',
#   'symbol': 'BINANCE:BGBPUSDC'},
#  {'description': 'Binance REEF/BUSD',
#   'displaySymbol': 'REEF/BUSD',
#   'symbol': 'BINANCE:REEFBUSD'},
#  {'description': 'Binance TCT/USDT',
#   'displaySymbol': 'TCT/USDT',
#   'symbol': 'BINANCE:TCTUSDT'},
#  {'description': 'Binance LTO/BUSD',
#   'displaySymbol': 'LTO/BUSD',
#   'symbol': 'BINANCE:LTOBUSD'},
#  {'description': 'Binance AUDIO/BTC',
#   'displaySymbol': 'AUDIO/BTC',
#   'symbol': 'BINANCE:AUDIOBTC'},
#  {'description': 'Binance ARPA/BUSD',
#   'displaySymbol': 'ARPA/BUSD',
#   'symbol': 'BINANCE:ARPABUSD'},
#  {'description': 'Binance CAKE/BTC',
#   'displaySymbol': 'CAKE/BTC',
#   'symbol': 'BINANCE:CAKEBTC'},
#  {'description': 'Binance CTK/BNB',
#   'displaySymbol': 'CTK/BNB',
#   'symbol': 'BINANCE:CTKBNB'},
#  {'description': 'Binance EOS/USDT',
#   'displaySymbol': 'EOS/USDT',
#   'symbol': 'BINANCE:EOSUSDT'},
#  {'description': 'Binance BNT/BTC',
#   'displaySymbol': 'BNT/BTC',
#   'symbol': 'BINANCE:BNTBTC'},
#  {'description': 'Binance BCH/EUR',
#   'displaySymbol': 'BCH/EUR',
#   'symbol': 'BINANCE:BCHEUR'},
#  {'description': 'Binance CFX/BUSD',
#   'displaySymbol': 'CFX/BUSD',
#   'symbol': 'BINANCE:CFXBUSD'},
#  {'description': 'Binance CAKE/BRL',
#   'displaySymbol': 'CAKE/BRL',
#   'symbol': 'BINANCE:CAKEBRL'},
#  {'description': 'Binance ADA/BUSD',
#   'displaySymbol': 'ADA/BUSD',
#   'symbol': 'BINANCE:ADABUSD'},
#  {'description': 'Binance NPXS/ETH',
#   'displaySymbol': 'NPXS/ETH',
#   'symbol': 'BINANCE:NPXSETH'},
#  {'description': 'Binance FIDA/USDT',
#   'displaySymbol': 'FIDA/USDT',
#   'symbol': 'BINANCE:FIDAUSDT'},
#  {'description': 'Binance LSK/USDT',
#   'displaySymbol': 'LSK/USDT',
#   'symbol': 'BINANCE:LSKUSDT'},
#  {'description': 'Binance DOT/BUSD',
#   'displaySymbol': 'DOT/BUSD',
#   'symbol': 'BINANCE:DOTBUSD'},
#  {'description': 'Binance DOGE/EUR',
#   'displaySymbol': 'DOGE/EUR',
#   'symbol': 'BINANCE:DOGEEUR'},
#  {'description': 'Binance AVAX/USDT',
#   'displaySymbol': 'AVAX/USDT',
#   'symbol': 'BINANCE:AVAXUSDT'},
#  {'description': 'Binance WING/BNB',
#   'displaySymbol': 'WING/BNB',
#   'symbol': 'BINANCE:WINGBNB'},
#  {'description': 'Binance MATIC/BTC',
#   'displaySymbol': 'MATIC/BTC',
#   'symbol': 'BINANCE:MATICBTC'},
#  {'description': 'Binance SUPER/BTC',
#   'displaySymbol': 'SUPER/BTC',
#   'symbol': 'BINANCE:SUPERBTC'},
#  {'description': 'Binance POLY/USDT',
#   'displaySymbol': 'POLY/USDT',
#   'symbol': 'BINANCE:POLYUSDT'},
#  {'description': 'Binance ADA/AUD',
#   'displaySymbol': 'ADA/AUD',
#   'symbol': 'BINANCE:ADAAUD'},
#  {'description': 'Binance AAVEUP/USDT',
#   'displaySymbol': 'AAVEUP/USDT',
#   'symbol': 'BINANCE:AAVEUPUSDT'},
#  {'description': 'Binance MDX/BNB',
#   'displaySymbol': 'MDX/BNB',
#   'symbol': 'BINANCE:MDXBNB'},
#  {'description': 'Binance BTC/TRY',
#   'displaySymbol': 'BTC/TRY',
#   'symbol': 'BINANCE:BTCTRY'},
#  {'description': 'Binance PSG/BUSD',
#   'displaySymbol': 'PSG/BUSD',
#   'symbol': 'BINANCE:PSGBUSD'},
#  {'description': 'Binance MATIC/BRL',
#   'displaySymbol': 'MATIC/BRL',
#   'symbol': 'BINANCE:MATICBRL'},
#  {'description': 'Binance SXP/USDT',
#   'displaySymbol': 'SXP/USDT',
#   'symbol': 'BINANCE:SXPUSDT'},
#  {'description': 'Binance DGD/ETH',
#   'displaySymbol': 'DGD/ETH',
#   'symbol': 'BINANCE:DGDETH'},
#  {'description': 'Binance IOTA/USDT',
#   'displaySymbol': 'IOTA/USDT',
#   'symbol': 'BINANCE:IOTAUSDT'},
#  {'description': 'Binance USDC/BUSD',
#   'displaySymbol': 'USDC/BUSD',
#   'symbol': 'BINANCE:USDCBUSD'},
#  {'description': 'Binance WAVES/ETH',
#   'displaySymbol': 'WAVES/ETH',
#   'symbol': 'BINANCE:WAVESETH'},
#  {'description': 'Binance ETC/USDC',
#   'displaySymbol': 'ETC/USDC',
#   'symbol': 'BINANCE:ETCUSDC'},
#  {'description': 'Binance SC/USDT',
#   'displaySymbol': 'SC/USDT',
#   'symbol': 'BINANCE:SCUSDT'},
#  {'description': 'Binance DYDX/BTC',
#   'displaySymbol': 'DYDX/BTC',
#   'symbol': 'BINANCE:DYDXBTC'},
#  {'description': 'Binance GNO/BUSD',
#   'displaySymbol': 'GNO/BUSD',
#   'symbol': 'BINANCE:GNOBUSD'},
#  {'description': 'Binance TRIG/BTC',
#   'displaySymbol': 'TRIG/BTC',
#   'symbol': 'BINANCE:TRIGBTC'},
#  {'description': 'Binance EZ/BTC',
#   'displaySymbol': 'EZ/BTC',
#   'symbol': 'BINANCE:EZBTC'},
#  {'description': 'Binance NANO/BNB',
#   'displaySymbol': 'NANO/BNB',
#   'symbol': 'BINANCE:NANOBNB'},
#  {'description': 'Binance COS/BNB',
#   'displaySymbol': 'COS/BNB',
#   'symbol': 'BINANCE:COSBNB'},
#  {'description': 'Binance PAXG/BUSD',
#   'displaySymbol': 'PAXG/BUSD',
#   'symbol': 'BINANCE:PAXGBUSD'},
#  {'description': 'Binance TRIG/ETH',
#   'displaySymbol': 'TRIG/ETH',
#   'symbol': 'BINANCE:TRIGETH'},
#  {'description': 'Binance SOL/TRY',
#   'displaySymbol': 'SOL/TRY',
#   'symbol': 'BINANCE:SOLTRY'},
#  {'description': 'Binance BNBUP/USDT',
#   'displaySymbol': 'BNBUP/USDT',
#   'symbol': 'BINANCE:BNBUPUSDT'},
#  {'description': 'Binance BURGER/BNB',
#   'displaySymbol': 'BURGER/BNB',
#   'symbol': 'BINANCE:BURGERBNB'},
#  {'description': 'Binance UNI/AUD',
#   'displaySymbol': 'UNI/AUD',
#   'symbol': 'BINANCE:UNIAUD'},
#  {'description': 'Binance PUNDIX/USDT',
#   'displaySymbol': 'PUNDIX/USDT',
#   'symbol': 'BINANCE:PUNDIXUSDT'},
#  {'description': 'Binance BCHABC/TUSD',
#   'displaySymbol': 'BCHABC/TUSD',
#   'symbol': 'BINANCE:BCHABCTUSD'},
#  {'description': 'Binance CELO/BTC',
#   'displaySymbol': 'CELO/BTC',
#   'symbol': 'BINANCE:CELOBTC'},
#  {'description': 'Binance USDS/TUSD',
#   'displaySymbol': 'USDS/TUSD',
#   'symbol': 'BINANCE:USDSTUSD'},
#  {'description': 'Binance TUSD/BUSD',
#   'displaySymbol': 'TUSD/BUSD',
#   'symbol': 'BINANCE:TUSDBUSD'},
#  {'description': 'Binance DIA/BUSD',
#   'displaySymbol': 'DIA/BUSD',
#   'symbol': 'BINANCE:DIABUSD'},
#  {'description': 'Binance KMD/BTC',
#   'displaySymbol': 'KMD/BTC',
#   'symbol': 'BINANCE:KMDBTC'},
#  {'description': 'Binance XRP/PAX',
#   'displaySymbol': 'XRP/PAX',
#   'symbol': 'BINANCE:XRPPAX'},
#  {'description': 'Binance BZRX/BTC',
#   'displaySymbol': 'BZRX/BTC',
#   'symbol': 'BINANCE:BZRXBTC'},
#  {'description': 'Binance XLMDOWN/USDT',
#   'displaySymbol': 'XLMDOWN/USDT',
#   'symbol': 'BINANCE:XLMDOWNUSDT'},
#  {'description': 'Binance IOTX/ETH',
#   'displaySymbol': 'IOTX/ETH',
#   'symbol': 'BINANCE:IOTXETH'},
#  {'description': 'Binance OM/USDT',
#   'displaySymbol': 'OM/USDT',
#   'symbol': 'BINANCE:OMUSDT'},
#  {'description': 'Binance BTC/UAH',
#   'displaySymbol': 'BTC/UAH',
#   'symbol': 'BINANCE:BTCUAH'},
#  {'description': 'Binance GRT/USDT',
#   'displaySymbol': 'GRT/USDT',
#   'symbol': 'BINANCE:GRTUSDT'},
#  {'description': 'Binance VET/BNB',
#   'displaySymbol': 'VET/BNB',
#   'symbol': 'BINANCE:VETBNB'},
#  {'description': 'Binance ARDR/BNB',
#   'displaySymbol': 'ARDR/BNB',
#   'symbol': 'BINANCE:ARDRBNB'},
#  {'description': 'Binance WIN/BUSD',
#   'displaySymbol': 'WIN/BUSD',
#   'symbol': 'BINANCE:WINBUSD'},
#  {'description': 'Binance SYS/BNB',
#   'displaySymbol': 'SYS/BNB',
#   'symbol': 'BINANCE:SYSBNB'},
#  {'description': 'Binance THETA/ETH',
#   'displaySymbol': 'THETA/ETH',
#   'symbol': 'BINANCE:THETAETH'},
#  {'description': 'Binance AMB/BNB',
#   'displaySymbol': 'AMB/BNB',
#   'symbol': 'BINANCE:AMBBNB'},
#  {'description': 'Binance SYS/BTC',
#   'displaySymbol': 'SYS/BTC',
#   'symbol': 'BINANCE:SYSBTC'},
#  {'description': 'Binance AKRO/USDT',
#   'displaySymbol': 'AKRO/USDT',
#   'symbol': 'BINANCE:AKROUSDT'},
#  {'description': 'Binance VITE/BNB',
#   'displaySymbol': 'VITE/BNB',
#   'symbol': 'BINANCE:VITEBNB'},
#  {'description': 'Binance FTM/BNB',
#   'displaySymbol': 'FTM/BNB',
#   'symbol': 'BINANCE:FTMBNB'},
#  {'description': 'Binance ZRX/USDT',
#   'displaySymbol': 'ZRX/USDT',
#   'symbol': 'BINANCE:ZRXUSDT'},
#  {'description': 'Binance ERD/BNB',
#   'displaySymbol': 'ERD/BNB',
#   'symbol': 'BINANCE:ERDBNB'},
#  {'description': 'Binance HOT/EUR',
#   'displaySymbol': 'HOT/EUR',
#   'symbol': 'BINANCE:HOTEUR'},
#  {'description': 'Binance LTC/USDC',
#   'displaySymbol': 'LTC/USDC',
#   'symbol': 'BINANCE:LTCUSDC'},
#  {'description': 'Binance TWT/USDT',
#   'displaySymbol': 'TWT/USDT',
#   'symbol': 'BINANCE:TWTUSDT'},
#  {'description': 'Binance CREAM/BUSD',
#   'displaySymbol': 'CREAM/BUSD',
#   'symbol': 'BINANCE:CREAMBUSD'},
#  {'description': 'Binance RVN/BUSD',
#   'displaySymbol': 'RVN/BUSD',
#   'symbol': 'BINANCE:RVNBUSD'},
#  {'description': 'Binance TRX/NGN',
#   'displaySymbol': 'TRX/NGN',
#   'symbol': 'BINANCE:TRXNGN'},
#  {'description': 'Binance AAVE/BNB',
#   'displaySymbol': 'AAVE/BNB',
#   'symbol': 'BINANCE:AAVEBNB'},
#  {'description': 'Binance BCHSV/BTC',
#   'displaySymbol': 'BCHSV/BTC',
#   'symbol': 'BINANCE:BCHSVBTC'},
#  {'description': 'Binance BLZ/USDT',
#   'displaySymbol': 'BLZ/USDT',
#   'symbol': 'BINANCE:BLZUSDT'},
#  {'description': 'Binance BCHABC/BUSD',
#   'displaySymbol': 'BCHABC/BUSD',
#   'symbol': 'BINANCE:BCHABCBUSD'},
#  {'description': 'Binance BAKE/BTC',
#   'displaySymbol': 'BAKE/BTC',
#   'symbol': 'BINANCE:BAKEBTC'},
#  {'description': 'Binance MIR/BTC',
#   'displaySymbol': 'MIR/BTC',
#   'symbol': 'BINANCE:MIRBTC'},
#  {'description': 'Binance LUNA/BTC',
#   'displaySymbol': 'LUNA/BTC',
#   'symbol': 'BINANCE:LUNABTC'},
#  {'description': 'Binance XLM/TUSD',
#   'displaySymbol': 'XLM/TUSD',
#   'symbol': 'BINANCE:XLMTUSD'},
#  {'description': 'Binance FRONT/BTC',
#   'displaySymbol': 'FRONT/BTC',
#   'symbol': 'BINANCE:FRONTBTC'},
#  {'description': 'Binance SUPER/USDT',
#   'displaySymbol': 'SUPER/USDT',
#   'symbol': 'BINANCE:SUPERUSDT'},
#  {'description': 'Binance ETH/DAI',
#   'displaySymbol': 'ETH/DAI',
#   'symbol': 'BINANCE:ETHDAI'},
#  {'description': 'Binance DENT/BTC',
#   'displaySymbol': 'DENT/BTC',
#   'symbol': 'BINANCE:DENTBTC'},
#  {'description': 'Binance WABI/ETH',
#   'displaySymbol': 'WABI/ETH',
#   'symbol': 'BINANCE:WABIETH'},
#  {'description': 'Binance VGX/ETH',
#   'displaySymbol': 'VGX/ETH',
#   'symbol': 'BINANCE:VGXETH'},
#  {'description': 'Binance GNT/BTC',
#   'displaySymbol': 'GNT/BTC',
#   'symbol': 'BINANCE:GNTBTC'},
#  {'description': 'Binance REN/USDT',
#   'displaySymbol': 'REN/USDT',
#   'symbol': 'BINANCE:RENUSDT'},
#  {'description': 'Binance TRIBE/BTC',
#   'displaySymbol': 'TRIBE/BTC',
#   'symbol': 'BINANCE:TRIBEBTC'},
#  {'description': 'Binance BETA/BUSD',
#   'displaySymbol': 'BETA/BUSD',
#   'symbol': 'BINANCE:BETABUSD'},
#  {'description': 'Binance AMB/BTC',
#   'displaySymbol': 'AMB/BTC',
#   'symbol': 'BINANCE:AMBBTC'},
#  {'description': 'Binance XRP/GBP',
#   'displaySymbol': 'XRP/GBP',
#   'symbol': 'BINANCE:XRPGBP'},
#  {'description': 'Binance DATA/ETH',
#   'displaySymbol': 'DATA/ETH',
#   'symbol': 'BINANCE:DATAETH'},
#  {'description': 'Binance ETH/PAX',
#   'displaySymbol': 'ETH/PAX',
#   'symbol': 'BINANCE:ETHPAX'},
#  {'description': 'Binance GO/BNB',
#   'displaySymbol': 'GO/BNB',
#   'symbol': 'BINANCE:GOBNB'},
#  {'description': 'Binance REP/BTC',
#   'displaySymbol': 'REP/BTC',
#   'symbol': 'BINANCE:REPBTC'},
#  {'description': 'Binance LIT/BTC',
#   'displaySymbol': 'LIT/BTC',
#   'symbol': 'BINANCE:LITBTC'},
#  {'description': 'Binance SWRV/BUSD',
#   'displaySymbol': 'SWRV/BUSD',
#   'symbol': 'BINANCE:SWRVBUSD'},
#  {'description': 'Binance ATM/BTC',
#   'displaySymbol': 'ATM/BTC',
#   'symbol': 'BINANCE:ATMBTC'},
#  {'description': 'Binance WRX/BTC',
#   'displaySymbol': 'WRX/BTC',
#   'symbol': 'BINANCE:WRXBTC'},
#  {'description': 'Binance SCRT/BTC',
#   'displaySymbol': 'SCRT/BTC',
#   'symbol': 'BINANCE:SCRTBTC'},
#  {'description': 'Binance OCEAN/BUSD',
#   'displaySymbol': 'OCEAN/BUSD',
#   'symbol': 'BINANCE:OCEANBUSD'},
#  {'description': 'Binance COCOS/BNB',
#   'displaySymbol': 'COCOS/BNB',
#   'symbol': 'BINANCE:COCOSBNB'},
#  {'description': 'Binance IQ/BUSD',
#   'displaySymbol': 'IQ/BUSD',
#   'symbol': 'BINANCE:IQBUSD'},
#  {'description': 'Binance XLM/USDT',
#   'displaySymbol': 'XLM/USDT',
#   'symbol': 'BINANCE:XLMUSDT'},
#  {'description': 'Binance BAKE/USDT',
#   'displaySymbol': 'BAKE/USDT',
#   'symbol': 'BINANCE:BAKEUSDT'},
#  {'description': 'Binance NU/BUSD',
#   'displaySymbol': 'NU/BUSD',
#   'symbol': 'BINANCE:NUBUSD'},
#  {'description': 'Binance OST/BNB',
#   'displaySymbol': 'OST/BNB',
#   'symbol': 'BINANCE:OSTBNB'},
#  {'description': 'Binance DOGE/PAX',
#   'displaySymbol': 'DOGE/PAX',
#   'symbol': 'BINANCE:DOGEPAX'},
#  {'description': 'Binance MITH/BNB',
#   'displaySymbol': 'MITH/BNB',
#   'symbol': 'BINANCE:MITHBNB'},
#  {'description': 'Binance APPC/BTC',
#   'displaySymbol': 'APPC/BTC',
#   'symbol': 'BINANCE:APPCBTC'},
#  {'description': 'Binance FTM/USDC',
#   'displaySymbol': 'FTM/USDC',
#   'symbol': 'BINANCE:FTMUSDC'},
#  {'description': 'Binance TRB/BTC',
#   'displaySymbol': 'TRB/BTC',
#   'symbol': 'BINANCE:TRBBTC'},
#  {'description': 'Binance LTC/BNB',
#   'displaySymbol': 'LTC/BNB',
#   'symbol': 'BINANCE:LTCBNB'},
#  {'description': 'Binance ETC/PAX',
#   'displaySymbol': 'ETC/PAX',
#   'symbol': 'BINANCE:ETCPAX'},
#  {'description': 'Binance MBL/BNB',
#   'displaySymbol': 'MBL/BNB',
#   'symbol': 'BINANCE:MBLBNB'},
#  {'description': 'Binance ALGO/BNB',
#   'displaySymbol': 'ALGO/BNB',
#   'symbol': 'BINANCE:ALGOBNB'},
#  {'description': 'Binance SUSHI/BNB',
#   'displaySymbol': 'SUSHI/BNB',
#   'symbol': 'BINANCE:SUSHIBNB'},
#  {'description': 'Binance USDT/RUB',
#   'displaySymbol': 'USDT/RUB',
#   'symbol': 'BINANCE:USDTRUB'},
#  {'description': 'Binance XZC/BTC',
#   'displaySymbol': 'XZC/BTC',
#   'symbol': 'BINANCE:XZCBTC'},
#  {'description': 'Binance CAKE/AUD',
#   'displaySymbol': 'CAKE/AUD',
#   'symbol': 'BINANCE:CAKEAUD'},
#  {'description': 'Binance NKN/BNB',
#   'displaySymbol': 'NKN/BNB',
#   'symbol': 'BINANCE:NKNBNB'},
#  {'description': 'Binance PNT/BTC',
#   'displaySymbol': 'PNT/BTC',
#   'symbol': 'BINANCE:PNTBTC'},
#  {'description': 'Binance STMX/BTC',
#   'displaySymbol': 'STMX/BTC',
#   'symbol': 'BINANCE:STMXBTC'},
#  {'description': 'Binance STMX/USDT',
#   'displaySymbol': 'STMX/USDT',
#   'symbol': 'BINANCE:STMXUSDT'},
#  {'description': 'Binance THETA/BTC',
#   'displaySymbol': 'THETA/BTC',
#   'symbol': 'BINANCE:THETABTC'},
#  {'description': 'Binance ONT/BTC',
#   'displaySymbol': 'ONT/BTC',
#   'symbol': 'BINANCE:ONTBTC'},
#  {'description': 'Binance DCR/BNB',
#   'displaySymbol': 'DCR/BNB',
#   'symbol': 'BINANCE:DCRBNB'},
#  {'description': 'Binance RLC/BUSD',
#   'displaySymbol': 'RLC/BUSD',
#   'symbol': 'BINANCE:RLCBUSD'},
#  {'description': 'Binance QUICK/USDT',
#   'displaySymbol': 'QUICK/USDT',
#   'symbol': 'BINANCE:QUICKUSDT'},
#  {'description': 'Binance KAVA/BNB',
#   'displaySymbol': 'KAVA/BNB',
#   'symbol': 'BINANCE:KAVABNB'},
#  {'description': 'Binance AVA/USDT',
#   'displaySymbol': 'AVA/USDT',
#   'symbol': 'BINANCE:AVAUSDT'},
#  {'description': 'Binance ROSE/BUSD',
#   'displaySymbol': 'ROSE/BUSD',
#   'symbol': 'BINANCE:ROSEBUSD'},
#  {'description': 'Binance BAT/BTC',
#   'displaySymbol': 'BAT/BTC',
#   'symbol': 'BINANCE:BATBTC'},
#  {'description': 'Binance WTC/BNB',
#   'displaySymbol': 'WTC/BNB',
#   'symbol': 'BINANCE:WTCBNB'},
#  {'description': 'Binance RAD/USDT',
#   'displaySymbol': 'RAD/USDT',
#   'symbol': 'BINANCE:RADUSDT'},
#  {'description': 'Binance GRT/TRY',
#   'displaySymbol': 'GRT/TRY',
#   'symbol': 'BINANCE:GRTTRY'},
#  {'description': 'Binance VGX/BTC',
#   'displaySymbol': 'VGX/BTC',
#   'symbol': 'BINANCE:VGXBTC'},
#  {'description': 'Binance RAMP/BUSD',
#   'displaySymbol': 'RAMP/BUSD',
#   'symbol': 'BINANCE:RAMPBUSD'},
#  {'description': 'Binance RIF/BTC',
#   'displaySymbol': 'RIF/BTC',
#   'symbol': 'BINANCE:RIFBTC'},
#  {'description': 'Binance NULS/ETH',
#   'displaySymbol': 'NULS/ETH',
#   'symbol': 'BINANCE:NULSETH'},
#  {'description': 'Binance LTC/BUSD',
#   'displaySymbol': 'LTC/BUSD',
#   'symbol': 'BINANCE:LTCBUSD'},
#  {'description': 'Binance STPT/BTC',
#   'displaySymbol': 'STPT/BTC',
#   'symbol': 'BINANCE:STPTBTC'},
#  {'description': 'Binance CLV/USDT',
#   'displaySymbol': 'CLV/USDT',
#   'symbol': 'BINANCE:CLVUSDT'},
#  {'description': 'Binance WIN/BTC',
#   'displaySymbol': 'WIN/BTC',
#   'symbol': 'BINANCE:WINBTC'},
#  {'description': 'Binance AXS/BNB',
#   'displaySymbol': 'AXS/BNB',
#   'symbol': 'BINANCE:AXSBNB'},
#  {'description': 'Binance SUSHIUP/USDT',
#   'displaySymbol': 'SUSHIUP/USDT',
#   'symbol': 'BINANCE:SUSHIUPUSDT'},
#  {'description': 'Binance BCHSV/PAX',
#   'displaySymbol': 'BCHSV/PAX',
#   'symbol': 'BINANCE:BCHSVPAX'},
#  {'description': 'Binance MANA/BTC',
#   'displaySymbol': 'MANA/BTC',
#   'symbol': 'BINANCE:MANABTC'},
#  {'description': 'Binance MBOX/BNB',
#   'displaySymbol': 'MBOX/BNB',
#   'symbol': 'BINANCE:MBOXBNB'},
#  {'description': 'Binance DODO/BTC',
#   'displaySymbol': 'DODO/BTC',
#   'symbol': 'BINANCE:DODOBTC'},
#  {'description': 'Binance ADX/BNB',
#   'displaySymbol': 'ADX/BNB',
#   'symbol': 'BINANCE:ADXBNB'},
#  {'description': 'Binance SHIB/BRL',
#   'displaySymbol': 'SHIB/BRL',
#   'symbol': 'BINANCE:SHIBBRL'},
#  {'description': 'Binance BNBBEAR/BUSD',
#   'displaySymbol': 'BNBBEAR/BUSD',
#   'symbol': 'BINANCE:BNBBEARBUSD'},
#  {'description': 'Binance LRC/ETH',
#   'displaySymbol': 'LRC/ETH',
#   'symbol': 'BINANCE:LRCETH'},
#  {'description': 'Binance XVG/BTC',
#   'displaySymbol': 'XVG/BTC',
#   'symbol': 'BINANCE:XVGBTC'},
#  {'description': 'Binance USDS/USDC',
#   'displaySymbol': 'USDS/USDC',
#   'symbol': 'BINANCE:USDSUSDC'},
#  {'description': 'Binance BCC/BTC',
#   'displaySymbol': 'BCC/BTC',
#   'symbol': 'BINANCE:BCCBTC'},
#  {'description': 'Binance SOL/BIDR',
#   'displaySymbol': 'SOL/BIDR',
#   'symbol': 'BINANCE:SOLBIDR'},
#  {'description': 'Binance GNT/BNB',
#   'displaySymbol': 'GNT/BNB',
#   'symbol': 'BINANCE:GNTBNB'},
#  {'description': 'Binance XMR/ETH',
#   'displaySymbol': 'XMR/ETH',
#   'symbol': 'BINANCE:XMRETH'},
#  {'description': 'Binance BTC/DAI',
#   'displaySymbol': 'BTC/DAI',
#   'symbol': 'BINANCE:BTCDAI'},
#  {'description': 'Binance WTC/ETH',
#   'displaySymbol': 'WTC/ETH',
#   'symbol': 'BINANCE:WTCETH'},
#  {'description': 'Binance ETH/BTC',
#   'displaySymbol': 'ETH/BTC',
#   'symbol': 'BINANCE:ETHBTC'},
#  {'description': 'Binance ALPHA/BTC',
#   'displaySymbol': 'ALPHA/BTC',
#   'symbol': 'BINANCE:ALPHABTC'},
#  {'description': 'Binance DF/USDT',
#   'displaySymbol': 'DF/USDT',
#   'symbol': 'BINANCE:DFUSDT'},
#  {'description': 'Binance BADGER/BUSD',
#   'displaySymbol': 'BADGER/BUSD',
#   'symbol': 'BINANCE:BADGERBUSD'},
#  {'description': 'Binance PAX/BTC',
#   'displaySymbol': 'PAX/BTC',
#   'symbol': 'BINANCE:PAXBTC'},
#  {'description': 'Binance ALICE/BIDR',
#   'displaySymbol': 'ALICE/BIDR',
#   'symbol': 'BINANCE:ALICEBIDR'},
#  {'description': 'Binance REP/USDT',
#   'displaySymbol': 'REP/USDT',
#   'symbol': 'BINANCE:REPUSDT'},
#  {'description': 'Binance PSG/BTC',
#   'displaySymbol': 'PSG/BTC',
#   'symbol': 'BINANCE:PSGBTC'},
#  {'description': 'Binance SOL/AUD',
#   'displaySymbol': 'SOL/AUD',
#   'symbol': 'BINANCE:SOLAUD'},
#  {'description': 'Binance GRT/ETH',
#   'displaySymbol': 'GRT/ETH',
#   'symbol': 'BINANCE:GRTETH'},
#  {'description': 'Binance INJ/BNB',
#   'displaySymbol': 'INJ/BNB',
#   'symbol': 'BINANCE:INJBNB'},
#  {'description': 'Binance XRP/BNB',
#   'displaySymbol': 'XRP/BNB',
#   'symbol': 'BINANCE:XRPBNB'},
#  {'description': 'Binance COTI/BUSD',
#   'displaySymbol': 'COTI/BUSD',
#   'symbol': 'BINANCE:COTIBUSD'},
#  {'description': 'Binance XMR/BUSD',
#   'displaySymbol': 'XMR/BUSD',
#   'symbol': 'BINANCE:XMRBUSD'},
#  {'description': 'Binance PERP/BTC',
#   'displaySymbol': 'PERP/BTC',
#   'symbol': 'BINANCE:PERPBTC'},
#  {'description': 'Binance BTG/ETH',
#   'displaySymbol': 'BTG/ETH',
#   'symbol': 'BINANCE:BTGETH'},
#  {'description': 'Binance XEM/BTC',
#   'displaySymbol': 'XEM/BTC',
#   'symbol': 'BINANCE:XEMBTC'},
#  {'description': 'Binance ERN/USDT',
#   'displaySymbol': 'ERN/USDT',
#   'symbol': 'BINANCE:ERNUSDT'},
#  {'description': 'Binance FUN/BTC',
#   'displaySymbol': 'FUN/BTC',
#   'symbol': 'BINANCE:FUNBTC'},
#  {'description': 'Binance ICX/BTC',
#   'displaySymbol': 'ICX/BTC',
#   'symbol': 'BINANCE:ICXBTC'},
#  {'description': 'Binance ELF/BTC',
#   'displaySymbol': 'ELF/BTC',
#   'symbol': 'BINANCE:ELFBTC'},
#  {'description': 'Binance SUB/BTC',
#   'displaySymbol': 'SUB/BTC',
#   'symbol': 'BINANCE:SUBBTC'},
#  {'description': 'Binance ILV/BTC',
#   'displaySymbol': 'ILV/BTC',
#   'symbol': 'BINANCE:ILVBTC'},
#  {'description': 'Binance FIO/BTC',
#   'displaySymbol': 'FIO/BTC',
#   'symbol': 'BINANCE:FIOBTC'},
#  {'description': 'Binance LTC/UAH',
#   'displaySymbol': 'LTC/UAH',
#   'symbol': 'BINANCE:LTCUAH'},
#  {'description': 'Binance LRC/BTC',
#   'displaySymbol': 'LRC/BTC',
#   'symbol': 'BINANCE:LRCBTC'},
#  {'description': 'Binance GRT/BTC',
#   'displaySymbol': 'GRT/BTC',
#   'symbol': 'BINANCE:GRTBTC'},
#  {'description': 'Binance POND/BTC',
#   'displaySymbol': 'POND/BTC',
#   'symbol': 'BINANCE:PONDBTC'},
#  {'description': 'Binance KNC/USDT',
#   'displaySymbol': 'KNC/USDT',
#   'symbol': 'BINANCE:KNCUSDT'},
#  {'description': 'Binance GRT/EUR',
#   'displaySymbol': 'GRT/EUR',
#   'symbol': 'BINANCE:GRTEUR'},
#  {'description': 'Binance NEAR/BUSD',
#   'displaySymbol': 'NEAR/BUSD',
#   'symbol': 'BINANCE:NEARBUSD'},
#  {'description': 'Binance TOMO/BUSD',
#   'displaySymbol': 'TOMO/BUSD',
#   'symbol': 'BINANCE:TOMOBUSD'},
#  {'description': 'Binance BEL/BTC',
#   'displaySymbol': 'BEL/BTC',
#   'symbol': 'BINANCE:BELBTC'},
#  {'description': 'Binance SAND/BTC',
#   'displaySymbol': 'SAND/BTC',
#   'symbol': 'BINANCE:SANDBTC'},
#  {'description': 'Binance ZIL/USDT',
#   'displaySymbol': 'ZIL/USDT',
#   'symbol': 'BINANCE:ZILUSDT'},
#  {'description': 'Binance WIN/BNB',
#   'displaySymbol': 'WIN/BNB',
#   'symbol': 'BINANCE:WINBNB'},
#  {'description': 'Binance PERP/BUSD',
#   'displaySymbol': 'PERP/BUSD',
#   'symbol': 'BINANCE:PERPBUSD'},
#  {'description': 'Binance AION/USDT',
#   'displaySymbol': 'AION/USDT',
#   'symbol': 'BINANCE:AIONUSDT'},
#  {'description': 'Binance ALPACA/USDT',
#   'displaySymbol': 'ALPACA/USDT',
#   'symbol': 'BINANCE:ALPACAUSDT'},
#  {'description': 'Binance XLMUP/USDT',
#   'displaySymbol': 'XLMUP/USDT',
#   'symbol': 'BINANCE:XLMUPUSDT'},
#  {'description': 'Binance ADX/BTC',
#   'displaySymbol': 'ADX/BTC',
#   'symbol': 'BINANCE:ADXBTC'},
#  {'description': 'Binance FLM/BUSD',
#   'displaySymbol': 'FLM/BUSD',
#   'symbol': 'BINANCE:FLMBUSD'},
#  {'description': 'Binance WIN/USDC',
#   'displaySymbol': 'WIN/USDC',
#   'symbol': 'BINANCE:WINUSDC'},
#  {'description': 'Binance BCPT/BTC',
#   'displaySymbol': 'BCPT/BTC',
#   'symbol': 'BINANCE:BCPTBTC'},
#  {'description': 'Binance MLN/BNB',
#   'displaySymbol': 'MLN/BNB',
#   'symbol': 'BINANCE:MLNBNB'},
#  {'description': 'Binance LINK/AUD',
#   'displaySymbol': 'LINK/AUD',
#   'symbol': 'BINANCE:LINKAUD'},
#  {'description': 'Binance BTC/GBP',
#   'displaySymbol': 'BTC/GBP',
#   'symbol': 'BINANCE:BTCGBP'},
#  {'description': 'Binance 1INCHDOWN/USDT',
#   'displaySymbol': '1INCHDOWN/USDT',
#   'symbol': 'BINANCE:1INCHDOWNUSDT'},
#  {'description': 'Binance PIVX/BTC',
#   'displaySymbol': 'PIVX/BTC',
#   'symbol': 'BINANCE:PIVXBTC'},
#  {'description': 'Binance PHB/USDC',
#   'displaySymbol': 'PHB/USDC',
#   'symbol': 'BINANCE:PHBUSDC'},
#  {'description': 'Binance ERD/USDC',
#   'displaySymbol': 'ERD/USDC',
#   'symbol': 'BINANCE:ERDUSDC'},
#  {'description': 'Binance FIO/USDT',
#   'displaySymbol': 'FIO/USDT',
#   'symbol': 'BINANCE:FIOUSDT'},
#  {'description': 'Binance NXS/BTC',
#   'displaySymbol': 'NXS/BTC',
#   'symbol': 'BINANCE:NXSBTC'},
#  {'description': 'Binance WAN/USDT',
#   'displaySymbol': 'WAN/USDT',
#   'symbol': 'BINANCE:WANUSDT'},
#  {'description': 'Binance ANKR/PAX',
#   'displaySymbol': 'ANKR/PAX',
#   'symbol': 'BINANCE:ANKRPAX'},
#  {'description': 'Binance BNB/TUSD',
#   'displaySymbol': 'BNB/TUSD',
#   'symbol': 'BINANCE:BNBTUSD'},
#  {'description': 'Binance AE/BNB',
#   'displaySymbol': 'AE/BNB',
#   'symbol': 'BINANCE:AEBNB'},
#  {'description': 'Binance ETH/UAH',
#   'displaySymbol': 'ETH/UAH',
#   'symbol': 'BINANCE:ETHUAH'},
#  {'description': 'Binance ZEC/BNB',
#   'displaySymbol': 'ZEC/BNB',
#   'symbol': 'BINANCE:ZECBNB'},
#  {'description': 'Binance WRX/BUSD',
#   'displaySymbol': 'WRX/BUSD',
#   'symbol': 'BINANCE:WRXBUSD'},
#  {'description': 'Binance MBL/BTC',
#   'displaySymbol': 'MBL/BTC',
#   'symbol': 'BINANCE:MBLBTC'},
#  {'description': 'Binance BURGER/USDT',
#   'displaySymbol': 'BURGER/USDT',
#   'symbol': 'BINANCE:BURGERUSDT'},
#  {'description': 'Binance DOGE/BRL',
#   'displaySymbol': 'DOGE/BRL',
#   'symbol': 'BINANCE:DOGEBRL'},
#  {'description': 'Binance WAVES/USDT',
#   'displaySymbol': 'WAVES/USDT',
#   'symbol': 'BINANCE:WAVESUSDT'},
#  {'description': 'Binance JUV/USDT',
#   'displaySymbol': 'JUV/USDT',
#   'symbol': 'BINANCE:JUVUSDT'},
#  {'description': 'Binance LINKDOWN/USDT',
#   'displaySymbol': 'LINKDOWN/USDT',
#   'symbol': 'BINANCE:LINKDOWNUSDT'},
#  {'description': 'Binance SOL/GBP',
#   'displaySymbol': 'SOL/GBP',
#   'symbol': 'BINANCE:SOLGBP'},
#  {'description': 'Binance XTZ/BNB',
#   'displaySymbol': 'XTZ/BNB',
#   'symbol': 'BINANCE:XTZBNB'},
#  {'description': 'Binance LTCDOWN/USDT',
#   'displaySymbol': 'LTCDOWN/USDT',
#   'symbol': 'BINANCE:LTCDOWNUSDT'},
#  {'description': 'Binance BTS/BTC',
#   'displaySymbol': 'BTS/BTC',
#   'symbol': 'BINANCE:BTSBTC'},
#  {'description': 'Binance ZEC/BUSD',
#   'displaySymbol': 'ZEC/BUSD',
#   'symbol': 'BINANCE:ZECBUSD'},
#  {'description': 'Binance KSM/USDT',
#   'displaySymbol': 'KSM/USDT',
#   'symbol': 'BINANCE:KSMUSDT'},
#  {'description': 'Binance COVER/ETH',
#   'displaySymbol': 'COVER/ETH',
#   'symbol': 'BINANCE:COVERETH'},
#  {'description': 'Binance ZIL/ETH',
#   'displaySymbol': 'ZIL/ETH',
#   'symbol': 'BINANCE:ZILETH'},
#  {'description': 'Binance SYS/USDT',
#   'displaySymbol': 'SYS/USDT',
#   'symbol': 'BINANCE:SYSUSDT'},
#  {'description': 'Binance CND/ETH',
#   'displaySymbol': 'CND/ETH',
#   'symbol': 'BINANCE:CNDETH'},
#  {'description': 'Binance DGD/BTC',
#   'displaySymbol': 'DGD/BTC',
#   'symbol': 'BINANCE:DGDBTC'},
#  {'description': 'Binance LTC/BTC',
#   'displaySymbol': 'LTC/BTC',
#   'symbol': 'BINANCE:LTCBTC'},
#  {'description': 'Binance ENG/ETH',
#   'displaySymbol': 'ENG/ETH',
#   'symbol': 'BINANCE:ENGETH'},
#  {'description': 'Binance HIVE/BTC',
#   'displaySymbol': 'HIVE/BTC',
#   'symbol': 'BINANCE:HIVEBTC'},
#  {'description': 'Binance GNO/BTC',
#   'displaySymbol': 'GNO/BTC',
#   'symbol': 'BINANCE:GNOBTC'},
#  {'description': 'Binance BTC/BRL',
#   'displaySymbol': 'BTC/BRL',
#   'symbol': 'BINANCE:BTCBRL'},
#  {'description': 'Binance LEND/BUSD',
#   'displaySymbol': 'LEND/BUSD',
#   'symbol': 'BINANCE:LENDBUSD'},
#  {'description': 'Binance XVS/USDT',
#   'displaySymbol': 'XVS/USDT',
#   'symbol': 'BINANCE:XVSUSDT'},
#  {'description': 'Binance BNB/USDC',
#   'displaySymbol': 'BNB/USDC',
#   'symbol': 'BINANCE:BNBUSDC'},
#  {'description': 'Binance BLZ/BUSD',
#   'displaySymbol': 'BLZ/BUSD',
#   'symbol': 'BINANCE:BLZBUSD'},
#  {'description': 'Binance ANT/BUSD',
#   'displaySymbol': 'ANT/BUSD',
#   'symbol': 'BINANCE:ANTBUSD'},
#  {'description': 'Binance BNB/BIDR',
#   'displaySymbol': 'BNB/BIDR',
#   'symbol': 'BINANCE:BNBBIDR'},
#  {'description': 'Binance JST/BNB',
#   'displaySymbol': 'JST/BNB',
#   'symbol': 'BINANCE:JSTBNB'},
#  {'description': 'Binance XRP/BTC',
#   'displaySymbol': 'XRP/BTC',
#   'symbol': 'BINANCE:XRPBTC'},
#  {'description': 'Binance XLM/ETH',
#   'displaySymbol': 'XLM/ETH',
#   'symbol': 'BINANCE:XLMETH'},
#  {'description': 'Binance FIRO/USDT',
#   'displaySymbol': 'FIRO/USDT',
#   'symbol': 'BINANCE:FIROUSDT'},
#  {'description': 'Binance DYDX/USDT',
#   'displaySymbol': 'DYDX/USDT',
#   'symbol': 'BINANCE:DYDXUSDT'},
#  {'description': 'Binance DOT/TRY',
#   'displaySymbol': 'DOT/TRY',
#   'symbol': 'BINANCE:DOTTRY'},
#  {'description': 'Binance XEC/BUSD',
#   'displaySymbol': 'XEC/BUSD',
#   'symbol': 'BINANCE:XECBUSD'},
#  {'description': 'Binance ETH/RUB',
#   'displaySymbol': 'ETH/RUB',
#   'symbol': 'BINANCE:ETHRUB'},
#  {'description': 'Binance ETH/USDC',
#   'displaySymbol': 'ETH/USDC',
#   'symbol': 'BINANCE:ETHUSDC'},
#  {'description': 'Binance BTC/NGN',
#   'displaySymbol': 'BTC/NGN',
#   'symbol': 'BINANCE:BTCNGN'},
#  {'description': 'Binance RVN/BNB',
#   'displaySymbol': 'RVN/BNB',
#   'symbol': 'BINANCE:RVNBNB'},
#  {'description': 'Binance ONT/USDC',
#   'displaySymbol': 'ONT/USDC',
#   'symbol': 'BINANCE:ONTUSDC'},
#  {'description': 'Binance QTUM/USDT',
#   'displaySymbol': 'QTUM/USDT',
#   'symbol': 'BINANCE:QTUMUSDT'},
#  {'description': 'Binance POWR/ETH',
#   'displaySymbol': 'POWR/ETH',
#   'symbol': 'BINANCE:POWRETH'},
#  {'description': 'Binance SOL/EUR',
#   'displaySymbol': 'SOL/EUR',
#   'symbol': 'BINANCE:SOLEUR'},
#  {'description': 'Binance PHA/BTC',
#   'displaySymbol': 'PHA/BTC',
#   'symbol': 'BINANCE:PHABTC'},
#  {'description': 'Binance BCPT/PAX',
#   'displaySymbol': 'BCPT/PAX',
#   'symbol': 'BINANCE:BCPTPAX'},
#  {'description': 'Binance CFX/BTC',
#   'displaySymbol': 'CFX/BTC',
#   'symbol': 'BINANCE:CFXBTC'},
#  {'description': 'Binance XRPBULL/BUSD',
#   'displaySymbol': 'XRPBULL/BUSD',
#   'symbol': 'BINANCE:XRPBULLBUSD'},
#  {'description': 'Binance RDN/BNB',
#   'displaySymbol': 'RDN/BNB',
#   'symbol': 'BINANCE:RDNBNB'},
#  {'description': 'Binance SHIB/BUSD',
#   'displaySymbol': 'SHIB/BUSD',
#   'symbol': 'BINANCE:SHIBBUSD'},
#  {'description': 'Binance BNB/UAH',
#   'displaySymbol': 'BNB/UAH',
#   'symbol': 'BINANCE:BNBUAH'},
#  {'description': 'Binance DYDX/BNB',
#   'displaySymbol': 'DYDX/BNB',
#   'symbol': 'BINANCE:DYDXBNB'},
#  {'description': 'Binance YFI/EUR',
#   'displaySymbol': 'YFI/EUR',
#   'symbol': 'BINANCE:YFIEUR'},
#  {'description': 'Binance HIVE/USDT',
#   'displaySymbol': 'HIVE/USDT',
#   'symbol': 'BINANCE:HIVEUSDT'},
#  {'description': 'Binance BZRX/BNB',
#   'displaySymbol': 'BZRX/BNB',
#   'symbol': 'BINANCE:BZRXBNB'},
#  {'description': 'Binance MFT/BNB',
#   'displaySymbol': 'MFT/BNB',
#   'symbol': 'BINANCE:MFTBNB'},
#  {'description': 'Binance KSM/BTC',
#   'displaySymbol': 'KSM/BTC',
#   'symbol': 'BINANCE:KSMBTC'},
#  {'description': 'Binance MTL/BTC',
#   'displaySymbol': 'MTL/BTC',
#   'symbol': 'BINANCE:MTLBTC'},
#  {'description': 'Binance TCT/BTC',
#   'displaySymbol': 'TCT/BTC',
#   'symbol': 'BINANCE:TCTBTC'},
#  {'description': 'Binance FIS/BRL',
#   'displaySymbol': 'FIS/BRL',
#   'symbol': 'BINANCE:FISBRL'},
#  {'description': 'Binance GHST/ETH',
#   'displaySymbol': 'GHST/ETH',
#   'symbol': 'BINANCE:GHSTETH'},
#  {'description': 'Binance ETC/ETH',
# ...
#  {'description': 'Binance IOTA/BUSD',
#   'displaySymbol': 'IOTA/BUSD',
#   'symbol': 'BINANCE:IOTABUSD'},
#  {'description': 'Binance ELF/BUSD',
#   'displaySymbol': 'ELF/BUSD',
#   'symbol': 'BINANCE:ELFBUSD'},
#  {'description': 'Binance VIBE/BTC',
#   'displaySymbol': 'VIBE/BTC',
#   'symbol': 'BINANCE:VIBEBTC'},
#  {'description': 'Binance RUNE/USDT',
#   'displaySymbol': 'RUNE/USDT',
#   'symbol': 'BINANCE:RUNEUSDT'},
#  {'description': 'Binance USDS/PAX',
#   'displaySymbol': 'USDS/PAX',
#   'symbol': 'BINANCE:USDSPAX'},
#  {'description': 'Binance WRX/USDT',
#   'displaySymbol': 'WRX/USDT',
#   'symbol': 'BINANCE:WRXUSDT'},
#  {'description': 'Binance PHA/USDT',
#   'displaySymbol': 'PHA/USDT',
#   'symbol': 'BINANCE:PHAUSDT'},
#  {'description': 'Binance NEAR/BNB',
#   'displaySymbol': 'NEAR/BNB',
#   'symbol': 'BINANCE:NEARBNB'},
#  {'description': 'Binance NEBL/BTC',
#   'displaySymbol': 'NEBL/BTC',
#   'symbol': 'BINANCE:NEBLBTC'},
#  {'description': 'Binance HOT/TRY',
#   'displaySymbol': 'HOT/TRY',
#   'symbol': 'BINANCE:HOTTRY'},
#  {'description': 'Binance APPC/BNB',
#   'displaySymbol': 'APPC/BNB',
#   'symbol': 'BINANCE:APPCBNB'},
#  {'description': 'Binance GTO/PAX',
#   'displaySymbol': 'GTO/PAX',
#   'symbol': 'BINANCE:GTOPAX'},
#  {'description': 'Binance CRV/USDT',
#   'displaySymbol': 'CRV/USDT',
#   'symbol': 'BINANCE:CRVUSDT'},
#  {'description': 'Binance RLC/ETH',
#   'displaySymbol': 'RLC/ETH',
#   'symbol': 'BINANCE:RLCETH'},
#  {'description': 'Binance OGN/BTC',
#   'displaySymbol': 'OGN/BTC',
#   'symbol': 'BINANCE:OGNBTC'},
#  {'description': 'Binance REP/BUSD',
#   'displaySymbol': 'REP/BUSD',
#   'symbol': 'BINANCE:REPBUSD'},
#  {'description': 'Binance NCASH/ETH',
#   'displaySymbol': 'NCASH/ETH',
#   'symbol': 'BINANCE:NCASHETH'},
#  {'description': 'Binance WAVES/USDC',
#   'displaySymbol': 'WAVES/USDC',
#   'symbol': 'BINANCE:WAVESUSDC'},
#  {'description': 'Binance AXS/BIDR',
#   'displaySymbol': 'AXS/BIDR',
#   'symbol': 'BINANCE:AXSBIDR'},
#  {'description': 'Binance BADGER/USDT',
#   'displaySymbol': 'BADGER/USDT',
#   'symbol': 'BINANCE:BADGERUSDT'},
#  {'description': 'Binance MATIC/USDT',
#   'displaySymbol': 'MATIC/USDT',
#   'symbol': 'BINANCE:MATICUSDT'},
#  {'description': 'Binance SC/BUSD',
#   'displaySymbol': 'SC/BUSD',
#   'symbol': 'BINANCE:SCBUSD'},
#  {'description': 'Binance USDSB/USDS',
#   'displaySymbol': 'USDSB/USDS',
#   'symbol': 'BINANCE:USDSBUSDS'},
#  {'description': 'Binance QUICK/BUSD',
#   'displaySymbol': 'QUICK/BUSD',
#   'symbol': 'BINANCE:QUICKBUSD'},
#  {'description': 'Binance AKRO/BTC',
#   'displaySymbol': 'AKRO/BTC',
#   'symbol': 'BINANCE:AKROBTC'},
#  {'description': 'Binance ARN/ETH',
#   'displaySymbol': 'ARN/ETH',
#   'symbol': 'BINANCE:ARNETH'},
#  {'description': 'Binance GALA/BNB',
#   'displaySymbol': 'GALA/BNB',
#   'symbol': 'BINANCE:GALABNB'},
#  {'description': 'Binance SXP/BUSD',
#   'displaySymbol': 'SXP/BUSD',
#   'symbol': 'BINANCE:SXPBUSD'},
#  {'description': 'Binance OCEAN/BTC',
#   'displaySymbol': 'OCEAN/BTC',
#   'symbol': 'BINANCE:OCEANBTC'},
#  {'description': 'Binance MLN/BTC',
#   'displaySymbol': 'MLN/BTC',
#   'symbol': 'BINANCE:MLNBTC'},
#  {'description': 'Binance STORM/USDT',
#   'displaySymbol': 'STORM/USDT',
#   'symbol': 'BINANCE:STORMUSDT'},
#  {'description': 'Binance AUTO/USDT',
#   'displaySymbol': 'AUTO/USDT',
#   'symbol': 'BINANCE:AUTOUSDT'},
#  {'description': 'Binance WAXP/BNB',
#   'displaySymbol': 'WAXP/BNB',
#   'symbol': 'BINANCE:WAXPBNB'},
#  {'description': 'Binance ACM/BUSD',
#   'displaySymbol': 'ACM/BUSD',
#   'symbol': 'BINANCE:ACMBUSD'},
#  {'description': 'Binance BTS/BUSD',
#   'displaySymbol': 'BTS/BUSD',
#   'symbol': 'BINANCE:BTSBUSD'},
#  {'description': 'Binance TRX/EUR',
#   'displaySymbol': 'TRX/EUR',
#   'symbol': 'BINANCE:TRXEUR'},
#  {'description': 'Binance ENJ/ETH',
#   'displaySymbol': 'ENJ/ETH',
#   'symbol': 'BINANCE:ENJETH'},
#  {'description': 'Binance CHZ/BRL',
#   'displaySymbol': 'CHZ/BRL',
#   'symbol': 'BINANCE:CHZBRL'},
#  {'description': 'Binance TUSD/BNB',
#   'displaySymbol': 'TUSD/BNB',
#   'symbol': 'BINANCE:TUSDBNB'},
#  {'description': 'Binance MIR/BUSD',
#   'displaySymbol': 'MIR/BUSD',
#   'symbol': 'BINANCE:MIRBUSD'},
#  {'description': 'Binance ONE/BTC',
#   'displaySymbol': 'ONE/BTC',
#   'symbol': 'BINANCE:ONEBTC'},
#  {'description': 'Binance FIRO/ETH',
#   'displaySymbol': 'FIRO/ETH',
#   'symbol': 'BINANCE:FIROETH'},
#  {'description': 'Binance TRXUP/USDT',
#   'displaySymbol': 'TRXUP/USDT',
#   'symbol': 'BINANCE:TRXUPUSDT'},
#  {'description': 'Binance FIL/BNB',
#   'displaySymbol': 'FIL/BNB',
#   'symbol': 'BINANCE:FILBNB'},
#  {'description': 'Binance BRD/ETH',
#   'displaySymbol': 'BRD/ETH',
#   'symbol': 'BINANCE:BRDETH'},
#  {'description': 'Binance MCO/ETH',
#   'displaySymbol': 'MCO/ETH',
#   'symbol': 'BINANCE:MCOETH'},
#  {'description': 'Binance FLM/BTC',
#   'displaySymbol': 'FLM/BTC',
#   'symbol': 'BINANCE:FLMBTC'},
#  {'description': 'Binance ICN/ETH',
#   'displaySymbol': 'ICN/ETH',
#   'symbol': 'BINANCE:ICNETH'},
#  {'description': 'Binance SHIB/AUD',
#   'displaySymbol': 'SHIB/AUD',
#   'symbol': 'BINANCE:SHIBAUD'},
#  {'description': 'Binance EUR/USDT',
#   'displaySymbol': 'EUR/USDT',
#   'symbol': 'BINANCE:EURUSDT'},
#  {'description': 'Binance BEAM/BNB',
#   'displaySymbol': 'BEAM/BNB',
#   'symbol': 'BINANCE:BEAMBNB'},
#  {'description': 'Binance MDX/USDT',
#   'displaySymbol': 'MDX/USDT',
#   'symbol': 'BINANCE:MDXUSDT'},
#  {'description': 'Binance CVP/BUSD',
#   'displaySymbol': 'CVP/BUSD',
#   'symbol': 'BINANCE:CVPBUSD'},
#  {'description': 'Binance SXP/TRY',
#   'displaySymbol': 'SXP/TRY',
#   'symbol': 'BINANCE:SXPTRY'},
#  {'description': 'Binance IRIS/BNB',
#   'displaySymbol': 'IRIS/BNB',
#   'symbol': 'BINANCE:IRISBNB'},
#  {'description': 'Binance GHST/BUSD',
#   'displaySymbol': 'GHST/BUSD',
#   'symbol': 'BINANCE:GHSTBUSD'},
#  {'description': 'Binance EOSBULL/BUSD',
#   'displaySymbol': 'EOSBULL/BUSD',
#   'symbol': 'BINANCE:EOSBULLBUSD'},
#  {'description': 'Binance LTO/BNB',
#   'displaySymbol': 'LTO/BNB',
#   'symbol': 'BINANCE:LTOBNB'},
#  {'description': 'Binance RLC/BTC',
#   'displaySymbol': 'RLC/BTC',
#   'symbol': 'BINANCE:RLCBTC'},
#  {'description': 'Binance BTT/BUSD',
#   'displaySymbol': 'BTT/BUSD',
#   'symbol': 'BINANCE:BTTBUSD'},
#  {'description': 'Binance HIVE/BNB',
#   'displaySymbol': 'HIVE/BNB',
#   'symbol': 'BINANCE:HIVEBNB'},
#  {'description': 'Binance THETA/BUSD',
#   'displaySymbol': 'THETA/BUSD',
#   'symbol': 'BINANCE:THETABUSD'},
#  {'description': 'Binance WAN/ETH',
#   'displaySymbol': 'WAN/ETH',
#   'symbol': 'BINANCE:WANETH'},
#  {'description': 'Binance XRP/USDT',
#   'displaySymbol': 'XRP/USDT',
#   'symbol': 'BINANCE:XRPUSDT'},
#  {'description': 'Binance LAZIO/USDT',
#   'displaySymbol': 'LAZIO/USDT',
#   'symbol': 'BINANCE:LAZIOUSDT'},
#  {'description': 'Binance TVK/BTC',
#   'displaySymbol': 'TVK/BTC',
#   'symbol': 'BINANCE:TVKBTC'},
#  {'description': 'Binance LSK/BUSD',
#   'displaySymbol': 'LSK/BUSD',
#   'symbol': 'BINANCE:LSKBUSD'},
#  {'description': 'Binance REN/BNB',
#   'displaySymbol': 'REN/BNB',
#   'symbol': 'BINANCE:RENBNB'},
#  {'description': 'Binance FIS/BUSD',
#   'displaySymbol': 'FIS/BUSD',
#   'symbol': 'BINANCE:FISBUSD'},
#  {'description': 'Binance COVER/BUSD',
#   'displaySymbol': 'COVER/BUSD',
#   'symbol': 'BINANCE:COVERBUSD'},
#  {'description': 'Binance ATM/BUSD',
#   'displaySymbol': 'ATM/BUSD',
#   'symbol': 'BINANCE:ATMBUSD'},
#  {'description': 'Binance BNB/BUSD',
#   'displaySymbol': 'BNB/BUSD',
#   'symbol': 'BINANCE:BNBBUSD'},
#  {'description': 'Binance MDX/BUSD',
#   'displaySymbol': 'MDX/BUSD',
#   'symbol': 'BINANCE:MDXBUSD'},
#  {'description': 'Binance BUSD/RUB',
#   'displaySymbol': 'BUSD/RUB',
#   'symbol': 'BINANCE:BUSDRUB'},
#  {'description': 'Binance EOS/BTC',
#   'displaySymbol': 'EOS/BTC',
#   'symbol': 'BINANCE:EOSBTC'},
#  {'description': 'Binance LINA/BUSD',
#   'displaySymbol': 'LINA/BUSD',
#   'symbol': 'BINANCE:LINABUSD'},
#  {'description': 'Binance MTL/USDT',
#   'displaySymbol': 'MTL/USDT',
#   'symbol': 'BINANCE:MTLUSDT'},
#  {'description': 'Binance PHB/TUSD',
#   'displaySymbol': 'PHB/TUSD',
#   'symbol': 'BINANCE:PHBTUSD'},
#  {'description': 'Binance MLN/USDT',
#   'displaySymbol': 'MLN/USDT',
#   'symbol': 'BINANCE:MLNUSDT'},
#  {'description': 'Binance TCT/BNB',
#   'displaySymbol': 'TCT/BNB',
#   'symbol': 'BINANCE:TCTBNB'},
#  {'description': 'Binance DOCK/BUSD',
#   'displaySymbol': 'DOCK/BUSD',
#   'symbol': 'BINANCE:DOCKBUSD'},
#  {'description': 'Binance SCRT/BUSD',
#   'displaySymbol': 'SCRT/BUSD',
#   'symbol': 'BINANCE:SCRTBUSD'},
#  {'description': 'Binance XLM/EUR',
#   'displaySymbol': 'XLM/EUR',
#   'symbol': 'BINANCE:XLMEUR'},
#  {'description': 'Binance ATOM/TUSD',
#   'displaySymbol': 'ATOM/TUSD',
#   'symbol': 'BINANCE:ATOMTUSD'},
#  {'description': 'Binance DUSK/BNB',
#   'displaySymbol': 'DUSK/BNB',
#   'symbol': 'BINANCE:DUSKBNB'},
#  {'description': 'Binance MTL/BUSD',
#   'displaySymbol': 'MTL/BUSD',
#   'symbol': 'BINANCE:MTLBUSD'},
#  {'description': 'Binance NANO/USDT',
#   'displaySymbol': 'NANO/USDT',
#   'symbol': 'BINANCE:NANOUSDT'},
#  {'description': 'Binance NEO/PAX',
#   'displaySymbol': 'NEO/PAX',
#   'symbol': 'BINANCE:NEOPAX'},
#  {'description': 'Binance BAND/BNB',
#   'displaySymbol': 'BAND/BNB',
#   'symbol': 'BINANCE:BANDBNB'},
#  {'description': 'Binance CELR/BTC',
#   'displaySymbol': 'CELR/BTC',
#   'symbol': 'BINANCE:CELRBTC'},
#  {'description': 'Binance XVG/BUSD',
#   'displaySymbol': 'XVG/BUSD',
#   'symbol': 'BINANCE:XVGBUSD'},
#  {'description': 'Binance CMT/ETH',
#   'displaySymbol': 'CMT/ETH',
#   'symbol': 'BINANCE:CMTETH'},
#  {'description': 'Binance NEBL/BNB',
#   'displaySymbol': 'NEBL/BNB',
#   'symbol': 'BINANCE:NEBLBNB'},
#  {'description': 'Binance RVN/BTC',
#   'displaySymbol': 'RVN/BTC',
#   'symbol': 'BINANCE:RVNBTC'},
#  {'description': 'Binance XTZ/BTC',
#   'displaySymbol': 'XTZ/BTC',
#   'symbol': 'BINANCE:XTZBTC'},
#  {'description': 'Binance IOTA/ETH',
#   'displaySymbol': 'IOTA/ETH',
#   'symbol': 'BINANCE:IOTAETH'},
#  {'description': 'Binance ARDR/USDT',
#   'displaySymbol': 'ARDR/USDT',
#   'symbol': 'BINANCE:ARDRUSDT'},
#  {'description': 'Binance DENT/BUSD',
#   'displaySymbol': 'DENT/BUSD',
#   'symbol': 'BINANCE:DENTBUSD'},
#  {'description': 'Binance BOND/BUSD',
#   'displaySymbol': 'BOND/BUSD',
#   'symbol': 'BINANCE:BONDBUSD'},
#  {'description': 'Binance NULS/BTC',
#   'displaySymbol': 'NULS/BTC',
#   'symbol': 'BINANCE:NULSBTC'},
#  {'description': 'Binance FIO/BUSD',
#   'displaySymbol': 'FIO/BUSD',
#   'symbol': 'BINANCE:FIOBUSD'},
#  {'description': 'Binance COTI/BTC',
#   'displaySymbol': 'COTI/BTC',
#   'symbol': 'BINANCE:COTIBTC'},
#  {'description': 'Binance DNT/USDT',
#   'displaySymbol': 'DNT/USDT',
#   'symbol': 'BINANCE:DNTUSDT'},
#  {'description': 'Binance BKRW/BUSD',
#   'displaySymbol': 'BKRW/BUSD',
#   'symbol': 'BINANCE:BKRWBUSD'},
#  {'description': 'Binance KEY/USDT',
#   'displaySymbol': 'KEY/USDT',
#   'symbol': 'BINANCE:KEYUSDT'},
#  {'description': 'Binance BNB/AUD',
#   'displaySymbol': 'BNB/AUD',
#   'symbol': 'BINANCE:BNBAUD'},
#  {'description': 'Binance USDP/USDT',
#   'displaySymbol': 'USDP/USDT',
#   'symbol': 'BINANCE:USDPUSDT'},
#  {'description': 'Binance PHB/PAX',
#   'displaySymbol': 'PHB/PAX',
#   'symbol': 'BINANCE:PHBPAX'},
#  {'description': 'Binance DENT/ETH',
#   'displaySymbol': 'DENT/ETH',
#   'symbol': 'BINANCE:DENTETH'},
#  {'description': 'Binance DOGE/BTC',
#   'displaySymbol': 'DOGE/BTC',
#   'symbol': 'BINANCE:DOGEBTC'},
#  {'description': 'Binance BAND/BUSD',
#   'displaySymbol': 'BAND/BUSD',
#   'symbol': 'BINANCE:BANDBUSD'},
#  {'description': 'Binance QTUM/BTC',
#   'displaySymbol': 'QTUM/BTC',
#   'symbol': 'BINANCE:QTUMBTC'},
#  {'description': 'Binance FRONT/USDT',
#   'displaySymbol': 'FRONT/USDT',
#   'symbol': 'BINANCE:FRONTUSDT'},
#  {'description': 'Binance BUSD/TRY',
#   'displaySymbol': 'BUSD/TRY',
#   'symbol': 'BINANCE:BUSDTRY'},
#  {'description': 'Binance NXS/BNB',
#   'displaySymbol': 'NXS/BNB',
#   'symbol': 'BINANCE:NXSBNB'},
#  {'description': 'Binance CLOAK/ETH',
#   'displaySymbol': 'CLOAK/ETH',
#   'symbol': 'BINANCE:CLOAKETH'},
#  {'description': 'Binance QTUM/BUSD',
#   'displaySymbol': 'QTUM/BUSD',
#   'symbol': 'BINANCE:QTUMBUSD'},
#  {'description': 'Binance GALA/USDT',
#   'displaySymbol': 'GALA/USDT',
#   'symbol': 'BINANCE:GALAUSDT'},
#  {'description': 'Binance ETH/USDT',
#   'displaySymbol': 'ETH/USDT',
#   'symbol': 'BINANCE:ETHUSDT'},
#  {'description': 'Binance BUSD/BVND',
#   'displaySymbol': 'BUSD/BVND',
#   'symbol': 'BINANCE:BUSDBVND'},
#  {'description': 'Binance COTI/BNB',
#   'displaySymbol': 'COTI/BNB',
#   'symbol': 'BINANCE:COTIBNB'},
#  {'description': 'Binance BCC/ETH',
#   'displaySymbol': 'BCC/ETH',
#   'symbol': 'BINANCE:BCCETH'},
#  {'description': 'Binance ETH/ZAR',
#   'displaySymbol': 'ETH/ZAR',
#   'symbol': 'BINANCE:ETHZAR'},
#  {'description': 'Binance XLM/USDC',
#   'displaySymbol': 'XLM/USDC',
#   'symbol': 'BINANCE:XLMUSDC'},
#  {'description': 'Binance BUSD/NGN',
#   'displaySymbol': 'BUSD/NGN',
#   'symbol': 'BINANCE:BUSDNGN'},
#  {'description': 'Binance PAX/BNB',
#   'displaySymbol': 'PAX/BNB',
#   'symbol': 'BINANCE:PAXBNB'},
#  {'description': 'Binance ZIL/BUSD',
#   'displaySymbol': 'ZIL/BUSD',
#   'symbol': 'BINANCE:ZILBUSD'},
#  {'description': 'Binance BADGER/BTC',
#   'displaySymbol': 'BADGER/BTC',
#   'symbol': 'BINANCE:BADGERBTC'},
#  {'description': 'Binance TVK/USDT',
#   'displaySymbol': 'TVK/USDT',
#   'symbol': 'BINANCE:TVKUSDT'},
#  {'description': 'Binance BCD/ETH',
#   'displaySymbol': 'BCD/ETH',
#   'symbol': 'BINANCE:BCDETH'},
#  {'description': 'Binance LINK/BTC',
#   'displaySymbol': 'LINK/BTC',
#   'symbol': 'BINANCE:LINKBTC'},
#  {'description': 'Binance AGLD/USDT',
#   'displaySymbol': 'AGLD/USDT',
#   'symbol': 'BINANCE:AGLDUSDT'},
#  {'description': 'Binance LIT/BUSD',
#   'displaySymbol': 'LIT/BUSD',
#   'symbol': 'BINANCE:LITBUSD'},
#  {'description': 'Binance FIRO/BTC',
#   'displaySymbol': 'FIRO/BTC',
#   'symbol': 'BINANCE:FIROBTC'},
#  {'description': 'Binance AR/USDT',
#   'displaySymbol': 'AR/USDT',
#   'symbol': 'BINANCE:ARUSDT'},
#  {'description': 'Binance ADA/GBP',
#   'displaySymbol': 'ADA/GBP',
#   'symbol': 'BINANCE:ADAGBP'},
#  {'description': 'Binance POLY/BTC',
#   'displaySymbol': 'POLY/BTC',
#   'symbol': 'BINANCE:POLYBTC'},
#  {'description': 'Binance RAY/USDT',
#   'displaySymbol': 'RAY/USDT',
#   'symbol': 'BINANCE:RAYUSDT'},
#  {'description': 'Binance DATA/BUSD',
#   'displaySymbol': 'DATA/BUSD',
#   'symbol': 'BINANCE:DATABUSD'},
#  {'description': 'Binance AUCTION/BTC',
#   'displaySymbol': 'AUCTION/BTC',
#   'symbol': 'BINANCE:AUCTIONBTC'},
#  {'description': 'Binance STRAX/USDT',
#   'displaySymbol': 'STRAX/USDT',
#   'symbol': 'BINANCE:STRAXUSDT'},
#  {'description': 'Binance DUSK/USDC',
#   'displaySymbol': 'DUSK/USDC',
#   'symbol': 'BINANCE:DUSKUSDC'},
#  {'description': 'Binance EOS/USDC',
#   'displaySymbol': 'EOS/USDC',
#   'symbol': 'BINANCE:EOSUSDC'},
#  {'description': 'Binance BAL/BTC',
#   'displaySymbol': 'BAL/BTC',
#   'symbol': 'BINANCE:BALBTC'},
#  {'description': 'Binance FTM/BIDR',
#   'displaySymbol': 'FTM/BIDR',
#   'symbol': 'BINANCE:FTMBIDR'},
#  {'description': 'Binance ZRX/BTC',
#   'displaySymbol': 'ZRX/BTC',
#   'symbol': 'BINANCE:ZRXBTC'},
#  {'description': 'Binance PERL/BNB',
#   'displaySymbol': 'PERL/BNB',
#   'symbol': 'BINANCE:PERLBNB'},
#  {'description': 'Binance BKRW/USDT',
#   'displaySymbol': 'BKRW/USDT',
#   'symbol': 'BINANCE:BKRWUSDT'},
#  {'description': 'Binance NKN/USDT',
#   'displaySymbol': 'NKN/USDT',
#   'symbol': 'BINANCE:NKNUSDT'},
#  {'description': 'Binance EOSUP/USDT',
#   'displaySymbol': 'EOSUP/USDT',
#   'symbol': 'BINANCE:EOSUPUSDT'},
#  {'description': 'Binance ADA/TUSD',
#   'displaySymbol': 'ADA/TUSD',
#   'symbol': 'BINANCE:ADATUSD'},
#  {'description': 'Binance BTG/USDT',
#   'displaySymbol': 'BTG/USDT',
#   'symbol': 'BINANCE:BTGUSDT'},
#  {'description': 'Binance JST/BTC',
#   'displaySymbol': 'JST/BTC',
#   'symbol': 'BINANCE:JSTBTC'},
#  {'description': 'Binance QSP/BTC',
#   'displaySymbol': 'QSP/BTC',
#   'symbol': 'BINANCE:QSPBTC'},
#  {'description': 'Binance AUTO/BTC',
#   'displaySymbol': 'AUTO/BTC',
#   'symbol': 'BINANCE:AUTOBTC'},
#  {'description': 'Binance STEEM/ETH',
#   'displaySymbol': 'STEEM/ETH',
#   'symbol': 'BINANCE:STEEMETH'},
#  {'description': 'Binance ALGO/TUSD',
#   'displaySymbol': 'ALGO/TUSD',
#   'symbol': 'BINANCE:ALGOTUSD'},
#  {'description': 'Binance EOS/TRY',
#   'displaySymbol': 'EOS/TRY',
#   'symbol': 'BINANCE:EOSTRY'},
#  {'description': 'Binance CHESS/BUSD',
#   'displaySymbol': 'CHESS/BUSD',
#   'symbol': 'BINANCE:CHESSBUSD'},
#  ...]

# %%
user.insert_one({
    'emailId': 'Kaustubhsharma999@gmail.com'
})

# %%
symbols.update_many({}, {'$set': {'dataSync': int(datetime(2020, 1, 1).timestamp())}})

# %%
def collect_day_data():
    for symbol in favList:

        currData = symbols.find_one({'base': symbol})
        try:
            df = pd.read_csv(dataLoc+symbol+'_1D.csv')
            exists = True
        except:
            df = None
            exists = False
        _from = currData['dataSync']
        till = int(datetime.now().timestamp())
        symbolSyntax = currData['symbol']
        res = fh.crypto_candles(symbolSyntax, 'D', _from, till)
        data = list()
        if res['s'] == 'no_data':
            print('Finished Sync for {0} with {1} rows'.format(symbol, len(data)))
            continue
        for count in range(len(res['t'])):
            rowDate = datetime.fromtimestamp(res['t'][count])
            data.append({
                'ts': res['t'][count],
                'date': rowDate,
                'dateDay': rowDate.day,
                'dateMonth': rowDate.month,
                'dateYear': rowDate.year,
                'open': res['o'][count],
                'close': res['c'][count],
                'high': res['h'][count],
                'low': res['l'][count],
                'volume': res['v'][count],
            })
        dfNew = pd.DataFrame(data)
        if exists:
            df = df.append(dfNew)
        else:
            df = dfNew.copy()
            
        df = df.drop_duplicates(subset=['ts'], keep='last')

        df.to_csv(dataLoc+symbol+'_1D.csv', index=False)

        symbols.update_one({'base': symbol}, {'$set': {'dataSync': max(res['t'])}})

        print('Finished Sync for {0} with {1} rows'.format(symbol, len(data)))

# %%
collect_day_data()
# Out:
# Starting Sync for BTC
# Finished Sync for BTC with 1 rows
# Starting Sync for ETH
# Finished Sync for ETH with 1 rows
# Starting Sync for ADA
# Finished Sync for ADA with 1 rows
# Starting Sync for SOL
# Finished Sync for SOL with 1 rows
# Starting Sync for XRP
# Finished Sync for XRP with 1 rows
# Starting Sync for MATIC
# Finished Sync for MATIC with 1 rows
# Starting Sync for BNB
# Finished Sync for BNB with 1 rows
# Starting Sync for LINK
# Finished Sync for LINK with 1 rows
# Starting Sync for LTC
# Finished Sync for LTC with 1 rows
# Starting Sync for EOS
# Finished Sync for EOS with 1 rows
# Starting Sync for BTT
# Finished Sync for BTT with 1 rows
# Starting Sync for TRX
# Finished Sync for TRX with 1 rows
# Starting Sync for VET
# Finished Sync for VET with 1 rows
# Starting Sync for QNT
# Finished Sync for QNT with 1 rows
# Starting Sync for CAKE
# Finished Sync for CAKE with 1 rows
# Starting Sync for HBAR
# Finished Sync for HBAR with 1 rows

# %%
df = pd.read_csv('../Data/ADA'+'_1H.csv')

# %%
df.iloc[-1]
# Out:
# Unnamed: 0                    479
# date          2021-10-31 15:30:00
# dateDay                        31
# dateMonth                      10
# dateYear                     2021
# dateHour                       15
# dateMinute                     30
# dateSecond                      0
# open                        1.955
# close                       1.944
# high                        1.956
# low                         1.939
# volume                  2813367.9
# Name: 479, dtype: object

# %%
def collect_hour_data():
    for symbol in favList:
    
        print('Starting Sync for {0}'.format(symbol))

        currData = symbols.find_one({'base': symbol})
        try:
            df = pd.read_csv(dataLoc+symbol+'_1H.csv')
            _from
            exists = True
        except:
            df = None
            exists = False
        today = datetime.now()
        till = int(today.timestamp())
        _from = int((datetime.now() - timedelta(days=20)).timestamp())
        symbolSyntax = currData['symbol']
        res = fh.crypto_candles(symbolSyntax, '60', _from, till)
        data = list()
        if res['s'] == 'no_data':
            print('Finished Sync for {0} with {1} rows'.format(symbol, len(data)))
            continue
        for count in range(len(res['t'])):
            date = datetime.fromtimestamp(res['t'][count])
            data.append({
                'date': date,
                'dateDay': date.day,
                'dateMonth': date.month,
                'dateYear': date.year,
                'dateHour': date.hour,
                'dateMinute': date.minute,
                'dateSecond': date.second,
                'open': res['o'][count],
                'close': res['c'][count],
                'high': res['h'][count],
                'low': res['l'][count],
                'volume': res['v'][count],
            })
        dfNew = pd.DataFrame(data)
        if exists:
            df = df.append(dfNew)
        else:
            df = dfNew.copy()

        df.to_csv(dataLoc+symbol+'_1H.csv')

        print('Finished Sync for {0} with {1} rows'.format(symbol, len(data)))

# %%
collect_hour_data()
# Out:
# Starting Sync for BTC
# Finished Sync for BTC with 480 rows
# Starting Sync for ETH
# Finished Sync for ETH with 480 rows
# Starting Sync for ADA
# Finished Sync for ADA with 480 rows
# Starting Sync for SOL
# Finished Sync for SOL with 480 rows
# Starting Sync for XRP
# Finished Sync for XRP with 480 rows
# Starting Sync for MATIC
# Finished Sync for MATIC with 480 rows
# Starting Sync for BNB
# Finished Sync for BNB with 480 rows
# Starting Sync for LINK
# Finished Sync for LINK with 480 rows
# Starting Sync for LTC
# Finished Sync for LTC with 480 rows
# Starting Sync for EOS
# Finished Sync for EOS with 480 rows
# Starting Sync for BTT
# Finished Sync for BTT with 480 rows
# Starting Sync for TRX
# Finished Sync for TRX with 480 rows
# Starting Sync for VET
# Finished Sync for VET with 480 rows
# Starting Sync for QNT
# Finished Sync for QNT with 480 rows
# Starting Sync for CAKE
# Finished Sync for CAKE with 480 rows
# Starting Sync for HBAR
# Finished Sync for HBAR with 480 rows

# %%
fh = finnhub.Client(api_key="c5tec52ad3ifck7dehd0")
for each in fh.crypto_symbols('BINANCE'):
    display = each['displaySymbol']
    symbol = each['symbol']
    base = display.split('/')[0]
    quote = display.split('/')[1]
    if quote == 'USDT':
        print(base, quote, symbol)
# Out:
# ARDR USDT BINANCE:ARDRUSDT
# DNT USDT BINANCE:DNTUSDT
# KEY USDT BINANCE:KEYUSDT
# USDP USDT BINANCE:USDPUSDT
# FRONT USDT BINANCE:FRONTUSDT
# GALA USDT BINANCE:GALAUSDT
# ETH USDT BINANCE:ETHUSDT
# TVK USDT BINANCE:TVKUSDT
# AGLD USDT BINANCE:AGLDUSDT
# AR USDT BINANCE:ARUSDT
# RAY USDT BINANCE:RAYUSDT
# STRAX USDT BINANCE:STRAXUSDT
# BKRW USDT BINANCE:BKRWUSDT
# NKN USDT BINANCE:NKNUSDT
# EOSUP USDT BINANCE:EOSUPUSDT
# BTG USDT BINANCE:BTGUSDT
# TRIBE USDT BINANCE:TRIBEUSDT
# LTCUP USDT BINANCE:LTCUPUSDT
# ONT USDT BINANCE:ONTUSDT
# DGB USDT BINANCE:DGBUSDT
# BAT USDT BINANCE:BATUSDT
# TUSD USDT BINANCE:TUSDUSDT
# XTZUP USDT BINANCE:XTZUPUSDT
# IRIS USDT BINANCE:IRISUSDT
# MINA USDT BINANCE:MINAUSDT
# ONG USDT BINANCE:ONGUSDT
# LINKUP USDT BINANCE:LINKUPUSDT
# ASR USDT BINANCE:ASRUSDT
# UMA USDT BINANCE:UMAUSDT
# QNT USDT BINANCE:QNTUSDT
# TRX USDT BINANCE:TRXUSDT
# ALPHA USDT BINANCE:ALPHAUSDT
# TKO USDT BINANCE:TKOUSDT
# FET USDT BINANCE:FETUSDT
# ELF USDT BINANCE:ELFUSDT
# TROY USDT BINANCE:TROYUSDT
# SFP USDT BINANCE:SFPUSDT
# BNT USDT BINANCE:BNTUSDT
# SXPDOWN USDT BINANCE:SXPDOWNUSDT
# PAX USDT BINANCE:PAXUSDT
# EOSDOWN USDT BINANCE:EOSDOWNUSDT
# CHESS USDT BINANCE:CHESSUSDT
# BCHDOWN USDT BINANCE:BCHDOWNUSDT
# KEEP USDT BINANCE:KEEPUSDT
# ETHBEAR USDT BINANCE:ETHBEARUSDT
# MIR USDT BINANCE:MIRUSDT
# ZEN USDT BINANCE:ZENUSDT
# ONE USDT BINANCE:ONEUSDT
# STPT USDT BINANCE:STPTUSDT
# SUN USDT BINANCE:SUNUSDT
# USDS USDT BINANCE:USDSUSDT
# ORN USDT BINANCE:ORNUSDT
# CVC USDT BINANCE:CVCUSDT
# MFT USDT BINANCE:MFTUSDT
# AUDIO USDT BINANCE:AUDIOUSDT
# WTC USDT BINANCE:WTCUSDT
# BCHUP USDT BINANCE:BCHUPUSDT
# CHR USDT BINANCE:CHRUSDT
# BEAM USDT BINANCE:BEAMUSDT
# DATA USDT BINANCE:DATAUSDT
# LEND USDT BINANCE:LENDUSDT
# MBOX USDT BINANCE:MBOXUSDT
# IOTX USDT BINANCE:IOTXUSDT
# DEXE USDT BINANCE:DEXEUSDT
# ERD USDT BINANCE:ERDUSDT
# BETA USDT BINANCE:BETAUSDT
# ADADOWN USDT BINANCE:ADADOWNUSDT
# KLAY USDT BINANCE:KLAYUSDT
# SHIB USDT BINANCE:SHIBUSDT
# WING USDT BINANCE:WINGUSDT
# GXS USDT BINANCE:GXSUSDT
# HC USDT BINANCE:HCUSDT
# GBP USDT BINANCE:GBPUSDT
# ROSE USDT BINANCE:ROSEUSDT
# ICX USDT BINANCE:ICXUSDT
# YFIUP USDT BINANCE:YFIUPUSDT
# CFX USDT BINANCE:CFXUSDT
# 1INCHUP USDT BINANCE:1INCHUPUSDT
# DREP USDT BINANCE:DREPUSDT
# LPT USDT BINANCE:LPTUSDT
# SRM USDT BINANCE:SRMUSDT
# JST USDT BINANCE:JSTUSDT
# POND USDT BINANCE:PONDUSDT
# BCHABC USDT BINANCE:BCHABCUSDT
# UNFI USDT BINANCE:UNFIUSDT
# BCH USDT BINANCE:BCHUSDT
# USDC USDT BINANCE:USDCUSDT
# NPXS USDT BINANCE:NPXSUSDT
# BNBBEAR USDT BINANCE:BNBBEARUSDT
# BNBDOWN USDT BINANCE:BNBDOWNUSDT
# XTZ USDT BINANCE:XTZUSDT
# MKR USDT BINANCE:MKRUSDT
# BNB USDT BINANCE:BNBUSDT
# PAXG USDT BINANCE:PAXGUSDT
# DEGO USDT BINANCE:DEGOUSDT
# SUSD USDT BINANCE:SUSDUSDT
# NULS USDT BINANCE:NULSUSDT
# XMR USDT BINANCE:XMRUSDT
# ATOM USDT BINANCE:ATOMUSDT
# ARPA USDT BINANCE:ARPAUSDT
# REEF USDT BINANCE:REEFUSDT
# CKB USDT BINANCE:CKBUSDT
# OXT USDT BINANCE:OXTUSDT
# ATM USDT BINANCE:ATMUSDT
# SOL USDT BINANCE:SOLUSDT
# ADA USDT BINANCE:ADAUSDT
# CTK USDT BINANCE:CTKUSDT
# HOT USDT BINANCE:HOTUSDT
# RARE USDT BINANCE:RAREUSDT
# UTK USDT BINANCE:UTKUSDT
# NEAR USDT BINANCE:NEARUSDT
# ILV USDT BINANCE:ILVUSDT
# HNT USDT BINANCE:HNTUSDT
# FLOW USDT BINANCE:FLOWUSDT
# WAXP USDT BINANCE:WAXPUSDT
# IOST USDT BINANCE:IOSTUSDT
# TOMO USDT BINANCE:TOMOUSDT
# ENJ USDT BINANCE:ENJUSDT
# COCOS USDT BINANCE:COCOSUSDT
# CELO USDT BINANCE:CELOUSDT
# VIDT USDT BINANCE:VIDTUSDT
# WNXM USDT BINANCE:WNXMUSDT
# TRB USDT BINANCE:TRBUSDT
# YGG USDT BINANCE:YGGUSDT
# ANKR USDT BINANCE:ANKRUSDT
# HARD USDT BINANCE:HARDUSDT
# BCHSV USDT BINANCE:BCHSVUSDT
# VITE USDT BINANCE:VITEUSDT
# FILDOWN USDT BINANCE:FILDOWNUSDT
# BTCUP USDT BINANCE:BTCUPUSDT
# CVP USDT BINANCE:CVPUSDT
# STX USDT BINANCE:STXUSDT
# MCO USDT BINANCE:MCOUSDT
# MANA USDT BINANCE:MANAUSDT
# KAVA USDT BINANCE:KAVAUSDT
# NEO USDT BINANCE:NEOUSDT
# BNBBULL USDT BINANCE:BNBBULLUSDT
# BAL USDT BINANCE:BALUSDT
# USDSB USDT BINANCE:USDSBUSDT
# STORJ USDT BINANCE:STORJUSDT
# FTT USDT BINANCE:FTTUSDT
# REQ USDT BINANCE:REQUSDT
# DASH USDT BINANCE:DASHUSDT
# BUSD USDT BINANCE:BUSDUSDT
# VEN USDT BINANCE:VENUSDT
# RAMP USDT BINANCE:RAMPUSDT
# FUN USDT BINANCE:FUNUSDT
# BTC USDT BINANCE:BTCUSDT
# PERL USDT BINANCE:PERLUSDT
# BTT USDT BINANCE:BTTUSDT
# BZRX USDT BINANCE:BZRXUSDT
# ADAUP USDT BINANCE:ADAUPUSDT
# NU USDT BINANCE:NUUSDT
# BCC USDT BINANCE:BCCUSDT
# ALICE USDT BINANCE:ALICEUSDT
# ETHBULL USDT BINANCE:ETHBULLUSDT
# BAND USDT BINANCE:BANDUSDT
# TORN USDT BINANCE:TORNUSDT
# YFI USDT BINANCE:YFIUSDT
# CAKE USDT BINANCE:CAKEUSDT
# OG USDT BINANCE:OGUSDT
# DIA USDT BINANCE:DIAUSDT
# XEC USDT BINANCE:XECUSDT
# AUD USDT BINANCE:AUDUSDT
# ETC USDT BINANCE:ETCUSDT
# AXS USDT BINANCE:AXSUSDT
# LTC USDT BINANCE:LTCUSDT
# DCR USDT BINANCE:DCRUSDT
# XEM USDT BINANCE:XEMUSDT
# ACM USDT BINANCE:ACMUSDT
# VET USDT BINANCE:VETUSDT
# FORTH USDT BINANCE:FORTHUSDT
# DUSK USDT BINANCE:DUSKUSDT
# ALGO USDT BINANCE:ALGOUSDT
# BAR USDT BINANCE:BARUSDT
# LRC USDT BINANCE:LRCUSDT
# IDEX USDT BINANCE:IDEXUSDT
# WIN USDT BINANCE:WINUSDT
# XRPUP USDT BINANCE:XRPUPUSDT
# XTZDOWN USDT BINANCE:XTZDOWNUSDT
# ANT USDT BINANCE:ANTUSDT
# GTC USDT BINANCE:GTCUSDT
# TRU USDT BINANCE:TRUUSDT
# BOND USDT BINANCE:BONDUSDT
# EPS USDT BINANCE:EPSUSDT
# DOTDOWN USDT BINANCE:DOTDOWNUSDT
# DOT USDT BINANCE:DOTUSDT
# SXPUP USDT BINANCE:SXPUPUSDT
# MASK USDT BINANCE:MASKUSDT
# LINA USDT BINANCE:LINAUSDT
# UNIDOWN USDT BINANCE:UNIDOWNUSDT
# PNT USDT BINANCE:PNTUSDT
# DOTUP USDT BINANCE:DOTUPUSDT
# CTSI USDT BINANCE:CTSIUSDT
# KMD USDT BINANCE:KMDUSDT
# RVN USDT BINANCE:RVNUSDT
# INJ USDT BINANCE:INJUSDT
# OMG USDT BINANCE:OMGUSDT
# XRPDOWN USDT BINANCE:XRPDOWNUSDT
# OCEAN USDT BINANCE:OCEANUSDT
# UNI USDT BINANCE:UNIUSDT
# MITH USDT BINANCE:MITHUSDT
# NBS USDT BINANCE:NBSUSDT
# TCT USDT BINANCE:TCTUSDT
# EOS USDT BINANCE:EOSUSDT
# FIDA USDT BINANCE:FIDAUSDT
# LSK USDT BINANCE:LSKUSDT
# AVAX USDT BINANCE:AVAXUSDT
# POLY USDT BINANCE:POLYUSDT
# AAVEUP USDT BINANCE:AAVEUPUSDT
# SXP USDT BINANCE:SXPUSDT
# IOTA USDT BINANCE:IOTAUSDT
# SC USDT BINANCE:SCUSDT
# BNBUP USDT BINANCE:BNBUPUSDT
# PUNDIX USDT BINANCE:PUNDIXUSDT
# XLMDOWN USDT BINANCE:XLMDOWNUSDT
# OM USDT BINANCE:OMUSDT
# GRT USDT BINANCE:GRTUSDT
# AKRO USDT BINANCE:AKROUSDT
# ZRX USDT BINANCE:ZRXUSDT
# TWT USDT BINANCE:TWTUSDT
# BLZ USDT BINANCE:BLZUSDT
# SUPER USDT BINANCE:SUPERUSDT
# REN USDT BINANCE:RENUSDT
# XLM USDT BINANCE:XLMUSDT
# BAKE USDT BINANCE:BAKEUSDT
# STMX USDT BINANCE:STMXUSDT
# QUICK USDT BINANCE:QUICKUSDT
# AVA USDT BINANCE:AVAUSDT
# RAD USDT BINANCE:RADUSDT
# CLV USDT BINANCE:CLVUSDT
# SUSHIUP USDT BINANCE:SUSHIUPUSDT
# DF USDT BINANCE:DFUSDT
# REP USDT BINANCE:REPUSDT
# ERN USDT BINANCE:ERNUSDT
# KNC USDT BINANCE:KNCUSDT
# ZIL USDT BINANCE:ZILUSDT
# AION USDT BINANCE:AIONUSDT
# ALPACA USDT BINANCE:ALPACAUSDT
# XLMUP USDT BINANCE:XLMUPUSDT
# 1INCHDOWN USDT BINANCE:1INCHDOWNUSDT
# FIO USDT BINANCE:FIOUSDT
# WAN USDT BINANCE:WANUSDT
# BURGER USDT BINANCE:BURGERUSDT
# WAVES USDT BINANCE:WAVESUSDT
# JUV USDT BINANCE:JUVUSDT
# LINKDOWN USDT BINANCE:LINKDOWNUSDT
# LTCDOWN USDT BINANCE:LTCDOWNUSDT
# KSM USDT BINANCE:KSMUSDT
# SYS USDT BINANCE:SYSUSDT
# XVS USDT BINANCE:XVSUSDT
# FIRO USDT BINANCE:FIROUSDT
# DYDX USDT BINANCE:DYDXUSDT
# QTUM USDT BINANCE:QTUMUSDT
# HIVE USDT BINANCE:HIVEUSDT
# DAI USDT BINANCE:DAIUSDT
# PSG USDT BINANCE:PSGUSDT
# COS USDT BINANCE:COSUSDT
# COMP USDT BINANCE:COMPUSDT
# EGLD USDT BINANCE:EGLDUSDT
# CHZ USDT BINANCE:CHZUSDT
# DODO USDT BINANCE:DODOUSDT
# DOGE USDT BINANCE:DOGEUSDT
# MBL USDT BINANCE:MBLUSDT
# LTO USDT BINANCE:LTOUSDT
# GTO USDT BINANCE:GTOUSDT
# NMR USDT BINANCE:NMRUSDT
# FIS USDT BINANCE:FISUSDT
# BTCDOWN USDT BINANCE:BTCDOWNUSDT
# FTM USDT BINANCE:FTMUSDT
# DOCK USDT BINANCE:DOCKUSDT
# EOSBULL USDT BINANCE:EOSBULLUSDT
# BEAR USDT BINANCE:BEARUSDT
# XVG USDT BINANCE:XVGUSDT
# SLP USDT BINANCE:SLPUSDT
# LINK USDT BINANCE:LINKUSDT
# EOSBEAR USDT BINANCE:EOSBEARUSDT
# CTXC USDT BINANCE:CTXCUSDT
# STRAT USDT BINANCE:STRATUSDT
# ETHUP USDT BINANCE:ETHUPUSDT
# ZEC USDT BINANCE:ZECUSDT
# HBAR USDT BINANCE:HBARUSDT
# RIF USDT BINANCE:RIFUSDT
# FLM USDT BINANCE:FLMUSDT
# AAVEDOWN USDT BINANCE:AAVEDOWNUSDT
# FOR USDT BINANCE:FORUSDT
# XZC USDT BINANCE:XZCUSDT
# LUNA USDT BINANCE:LUNAUSDT
# ICP USDT BINANCE:ICPUSDT
# FIL USDT BINANCE:FILUSDT
# THETA USDT BINANCE:THETAUSDT
# SAND USDT BINANCE:SANDUSDT
# ETHDOWN USDT BINANCE:ETHDOWNUSDT
# TFUEL USDT BINANCE:TFUELUSDT
# COTI USDT BINANCE:COTIUSDT
# XRPBULL USDT BINANCE:XRPBULLUSDT
# BTCST USDT BINANCE:BTCSTUSDT
# SUSHI USDT BINANCE:SUSHIUSDT
# SNX USDT BINANCE:SNXUSDT
# YFII USDT BINANCE:YFIIUSDT
# CELR USDT BINANCE:CELRUSDT
# LIT USDT BINANCE:LITUSDT
# VTHO USDT BINANCE:VTHOUSDT
# UNIUP USDT BINANCE:UNIUPUSDT
# YFIDOWN USDT BINANCE:YFIDOWNUSDT
# PERP USDT BINANCE:PERPUSDT
# OGN USDT BINANCE:OGNUSDT
# TLM USDT BINANCE:TLMUSDT
# GHST USDT BINANCE:GHSTUSDT
# BULL USDT BINANCE:BULLUSDT
# SUSHIDOWN USDT BINANCE:SUSHIDOWNUSDT
# BEL USDT BINANCE:BELUSDT
# AAVE USDT BINANCE:AAVEUSDT
# RSR USDT BINANCE:RSRUSDT
# GNO USDT BINANCE:GNOUSDT
# DENT USDT BINANCE:DENTUSDT
# BTS USDT BINANCE:BTSUSDT
# C98 USDT BINANCE:C98USDT
# MDT USDT BINANCE:MDTUSDT
# TRXDOWN USDT BINANCE:TRXDOWNUSDT
# 1INCH USDT BINANCE:1INCHUSDT
# FARM USDT BINANCE:FARMUSDT
# RLC USDT BINANCE:RLCUSDT
# SKL USDT BINANCE:SKLUSDT
# POLS USDT BINANCE:POLSUSDT
# FILUP USDT BINANCE:FILUPUSDT
# XRPBEAR USDT BINANCE:XRPBEARUSDT
# ATA USDT BINANCE:ATAUSDT
# RUNE USDT BINANCE:RUNEUSDT
# WRX USDT BINANCE:WRXUSDT
# PHA USDT BINANCE:PHAUSDT
# CRV USDT BINANCE:CRVUSDT
# BADGER USDT BINANCE:BADGERUSDT
# MATIC USDT BINANCE:MATICUSDT
# STORM USDT BINANCE:STORMUSDT
# AUTO USDT BINANCE:AUTOUSDT
# TRXUP USDT BINANCE:TRXUPUSDT
# EUR USDT BINANCE:EURUSDT
# MDX USDT BINANCE:MDXUSDT
# XRP USDT BINANCE:XRPUSDT
# LAZIO USDT BINANCE:LAZIOUSDT
# MTL USDT BINANCE:MTLUSDT
# MLN USDT BINANCE:MLNUSDT
# NANO USDT BINANCE:NANOUSDT
